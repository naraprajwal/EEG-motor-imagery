# %%
# ==========================================================
# CELL 1 — IMPORTS AND CONFIGURATION
# ==========================================================

import os
import random
import numpy as np
import matplotlib.pyplot as plt
import mne
import json

import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

from braindecode.models import ShallowFBCSPNet

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)


# ==========================================================
# REPRODUCIBILITY
# ==========================================================

SEED = 42

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)


# ==========================================================
# PATHS
# ==========================================================

EPOCH_DIR = (
    "/Users/prajwalnara/Documents/EEG-motor-imagery/"
    "data/processed/epochs"
)

# ==========================================================
# SAVED SHALLOW CONVNET DATASETS
# ==========================================================

SHALLOW_CONVNET_SPLIT_DIR = (
    "/Users/prajwalnara/Documents/EEG-motor-imagery/"
    "data/shallow_convnet_splits"
)

os.makedirs(
    SHALLOW_CONVNET_SPLIT_DIR,
    exist_ok=True
)

# ==========================================================
# RESULT DIRECTORY
# ==========================================================

SHALLOW_CONVNET_RESULT_DIR = (
    "/Users/prajwalnara/Documents/EEG-motor-imagery/"
    "results/shallow_convnet_results"
)
os.makedirs(
    SHALLOW_CONVNET_RESULT_DIR,
    exist_ok=True
)

# ==========================================================
# MODEL DIRECTORY
# ==========================================================
MODEL_DIR = (
    "/Users/prajwalnara/Documents/EEG-motor-imagery/"
    "models/shallow_convnet"
)
os.makedirs(
    MODEL_DIR,
    exist_ok=True
)


# ==========================================================
# DATA CONFIGURATION
# ==========================================================

RUNS = ["R04", "R08", "R12"]


# ==========================================================
# TRAINING CONFIGURATION
# ==========================================================

BATCH_SIZE = 16
LEARNING_RATE = 1e-3
NUM_EPOCHS = 100
N_CLASSES = 3
EXPECTED_N_TIMES = 641


# ==========================================================
# DEVICE
# ==========================================================

if torch.backends.mps.is_available():
    DEVICE = torch.device("mps")

elif torch.cuda.is_available():
    DEVICE = torch.device("cuda")

else:
    DEVICE = torch.device("cpu")


print("Device:", DEVICE)
print("PyTorch version:", torch.__version__)
# Out:
# Device: mps
# PyTorch version: 2.12.1

# %%
# ==========================================================
# CELL 2 — SUBJECT EPOCH LOADING FUNCTION
# ==========================================================

def load_subject_epochs(subject_list):
    """
    Load R04, R08 and R12 epochs for each subject.

    A subject is skipped if:
    - any required run file is missing
    - a run has an unexpected number of time points
    - run dimensions are inconsistent

    Returns
    -------
    subject_data : dict
        {
            "S001": {
                "X": (n_epochs, n_channels, n_times),
                "y": (n_epochs,)
            }
        }

    skipped_subjects : list
        Subjects that failed validation.
    """

    subject_data = {}
    skipped_subjects = []

    for subject in subject_list:

        subject_folder = os.path.join(
            EPOCH_DIR,
            subject
        )

        X_runs = []
        y_runs = []

        valid_subject = True


        # ==================================================
        # LOAD EACH RUN
        # ==================================================

        for run in RUNS:

            file_path = os.path.join(
                subject_folder,
                f"{subject}{run}_epo.fif"
            )


            # ----------------------------------------------
            # CHECK 1 — File exists
            # ----------------------------------------------

            if not os.path.exists(file_path):

                print(
                    f"{subject} skipped: "
                    f"missing {run}"
                )

                valid_subject = False
                break


            # ----------------------------------------------
            # Load epochs
            # ----------------------------------------------

            epochs = mne.read_epochs(
                file_path,
                preload=True,
                verbose=False
            )

            X_run = epochs.get_data()
            y_run = epochs.events[:, -1]


            # ----------------------------------------------
            # CHECK 2 — Expected number of time points
            # ----------------------------------------------

            if X_run.shape[2] != EXPECTED_N_TIMES:

                print(
                    f"{subject} skipped: "
                    f"{run} has {X_run.shape[2]} time points "
                    f"(expected {EXPECTED_N_TIMES})"
                )

                valid_subject = False
                break


            X_runs.append(X_run)
            y_runs.append(y_run)


        # ==================================================
        # SKIP INVALID SUBJECT
        # ==================================================

        if not valid_subject:

            skipped_subjects.append(subject)
            continue


        # ==================================================
        # CHECK 3 — RUN DIMENSIONS ARE CONSISTENT
        # ==================================================

        run_shapes = [
            X.shape[1:]
            for X in X_runs
        ]

        if len(set(run_shapes)) != 1:

            print(
                f"{subject} skipped: "
                f"inconsistent run shapes {run_shapes}"
            )

            skipped_subjects.append(subject)
            continue


        # ==================================================
        # COMBINE RUNS
        # ==================================================

        X_subject = np.concatenate(
            X_runs,
            axis=0
        )

        y_subject = np.concatenate(
            y_runs,
            axis=0
        )


        # ==================================================
        # STORE SUBJECT
        # ==================================================

        subject_data[subject] = {
            "X": X_subject,
            "y": y_subject
        }


    return subject_data, skipped_subjects

# %%
#LOADING ALL SUBJECTS AND MARKING OUT THE DEFAULTED EPCOHS
# ==========================================================
# CELL 3 — LOAD ALL SUBJECTS
# ==========================================================

ALL_SUBJECTS = [
    f"S{i:03d}"
    for i in range(1, 110)
]


subject_data, skipped_subjects = load_subject_epochs(
    ALL_SUBJECTS
)


print("=" * 60)
print("DATA LOADING SUMMARY")
print("=" * 60)

print("Requested subjects :", len(ALL_SUBJECTS))
print("Loaded subjects    :", len(subject_data))
print("Skipped subjects   :", len(skipped_subjects))

print("\nSkipped subject IDs:")
print(skipped_subjects)


sample_subject = next(iter(subject_data))

X_sample = subject_data[sample_subject]["X"]
y_sample = subject_data[sample_subject]["y"]


print("\nSample subject:", sample_subject)

print("X shape:", X_sample.shape)
print("y shape:", y_sample.shape)

print(
    "Labels:",
    np.unique(
        y_sample,
        return_counts=True
    )
)
# Out:
# S088 skipped: R04 has 513 time points (expected 641)
# S092 skipped: R04 has 513 time points (expected 641)
# S100 skipped: R04 has 513 time points (expected 641)
# ============================================================
# DATA LOADING SUMMARY
# ============================================================
# Requested subjects : 109
# Loaded subjects    : 106
# Skipped subjects   : 3
#
# Skipped subject IDs:
# ['S088', 'S092', 'S100']
#
# Sample subject: S001
# X shape: (90, 64, 641)
# y shape: (90,)
# Labels: (array([1, 2, 3], dtype=int32), array([45, 23, 22]))

# %%
# ==========================================================
# CELL 4 — EXPERIMENT CONFIGURATIONS
# ==========================================================

EXPERIMENTS = {

    "10 Subjects": {
        "train": [
            f"S{i:03d}"
            for i in range(1, 9)
        ],

        "test": [
            f"S{i:03d}"
            for i in range(9, 11)
        ]
    },


    "20 Subjects": {
        "train": [
            f"S{i:03d}"
            for i in range(1, 18)
        ],

        "test": [
            f"S{i:03d}"
            for i in range(18, 21)
        ]
    },


    "50 Subjects": {
        "train": [
            f"S{i:03d}"
            for i in range(1, 43)
        ],

        "test": [
            f"S{i:03d}"
            for i in range(43, 51)
        ]
    },


    "109 Subjects": {
        "train": [
            f"S{i:03d}"
            for i in range(1, 93)
        ],

        "test": [
            f"S{i:03d}"
            for i in range(93, 110)
        ]
    }
}

# %%
# ==========================================================
# CELL 5 — PREPARE EXPERIMENT DATA
# ==========================================================

LABEL_MAP = {
    1: 0,   # Rest
    2: 1,   # Left
    3: 2    # Right
}


def prepare_experiment_data(
    subject_data,
    train_subjects,
    test_subjects,
    val_ratio=0.10,
    seed=42
):

    # ======================================================
    # KEEP ONLY VALID SUBJECTS
    # ======================================================

    train_subjects = [
        subject
        for subject in train_subjects
        if subject in subject_data
    ]

    test_subjects = [
        subject
        for subject in test_subjects
        if subject in subject_data
    ]


    # ======================================================
    # SUBJECT-WISE TRAIN / VALIDATION SPLIT
    # ======================================================

    rng = np.random.default_rng(seed)

    shuffled_train_subjects = train_subjects.copy()

    rng.shuffle(shuffled_train_subjects)


    # At least one subject must be used for validation

    n_val_subjects = max(
        1,
        round(
            len(shuffled_train_subjects)
            * val_ratio
        )
    )


    val_subjects = shuffled_train_subjects[
        :n_val_subjects
    ]

    actual_train_subjects = shuffled_train_subjects[
        n_val_subjects:
    ]


    # ======================================================
    # HELPER FUNCTION TO COMBINE SUBJECT DATA
    # ======================================================

    def combine_subjects(subject_list):

        X = np.concatenate(
            [
                subject_data[subject]["X"]
                for subject in subject_list
            ],
            axis=0
        )

        y = np.concatenate(
            [
                subject_data[subject]["y"]
                for subject in subject_list
            ],
            axis=0
        )


        # ----------------------------------------------
        # Remap labels
        #
        # 1 → 0 : Rest
        # 2 → 1 : Left
        # 3 → 2 : Right
        # ----------------------------------------------

        y = np.array(
            [
                LABEL_MAP[label]
                for label in y
            ],
            dtype=np.int64
        )


        return X, y


    # ======================================================
    # CREATE TRAINING DATA
    # ======================================================

    X_train, y_train = combine_subjects(
        actual_train_subjects
    )


    # ======================================================
    # CREATE VALIDATION DATA
    # ======================================================

    X_val, y_val = combine_subjects(
        val_subjects
    )


    # ======================================================
    # CREATE TEST DATA
    # ======================================================

    X_test, y_test = combine_subjects(
        test_subjects
    )


    # ======================================================
    # STORE TEST SUBJECT ID FOR EACH EPOCH
    # ======================================================

    test_subject_ids = np.concatenate(
        [
            np.repeat(
                subject,
                len(subject_data[subject]["y"])
            )
            for subject in test_subjects
        ]
    )


    # ======================================================
    # PRINT SPLIT SUMMARY
    # ======================================================

    print("\n" + "=" * 60)
    print("SUBJECT SPLIT")
    print("=" * 60)

    print(
        "Training subjects   :",
        len(actual_train_subjects)
    )

    print(
        "Validation subjects :",
        len(val_subjects)
    )

    print(
        "Test subjects       :",
        len(test_subjects)
    )


    print("\nValidation subjects:")
    print(sorted(val_subjects))

    print("\nTest subjects:")
    print(sorted(test_subjects))


    print("\nData shapes:")

    print(
        "X_train:",
        X_train.shape
    )

    print(
        "X_val  :",
        X_val.shape
    )

    print(
        "X_test :",
        X_test.shape
    )


    return (
        X_train,
        y_train,
        X_val,
        y_val,
        X_test,
        y_test,
        test_subject_ids,
        actual_train_subjects,
        val_subjects,
        test_subjects
    )

# %%
# ==========================================================
# CELL 6 — NORMALIZE AND SAVE EXPERIMENT DATA
# ==========================================================

def normalize_data(
    X_train,
    X_val,
    X_test
):

    # ------------------------------------------------------
    # Convert to float32 to reduce memory usage
    # ------------------------------------------------------

    X_train = X_train.astype(
        np.float32,
        copy=False
    )

    X_val = X_val.astype(
        np.float32,
        copy=False
    )

    X_test = X_test.astype(
        np.float32,
        copy=False
    )


    # ------------------------------------------------------
    # Calculate statistics from TRAINING DATA ONLY
    #
    # axis 0 → epochs
    # axis 2 → time samples
    #
    # Separate mean/std for each EEG channel
    # ------------------------------------------------------

    channel_mean = X_train.mean(
        axis=(0, 2),
        keepdims=True
    )

    channel_std = X_train.std(
        axis=(0, 2),
        keepdims=True
    )


    # Avoid division by zero

    channel_std[
        channel_std < 1e-8
    ] = 1.0


    # ------------------------------------------------------
    # Apply training statistics to all three sets
    # ------------------------------------------------------

    X_train = (
        X_train - channel_mean
    ) / channel_std

    X_val = (
        X_val - channel_mean
    ) / channel_std

    X_test = (
        X_test - channel_mean
    ) / channel_std


    return (
        X_train,
        X_val,
        X_test,
        channel_mean,
        channel_std
    )

# %%
def save_experiment_data(
    experiment_name,
    X_train,
    y_train,
    X_val,
    y_val,
    X_test,
    y_test,
    test_subject_ids,
    channel_mean,
    channel_std
):

    # ------------------------------------------------------
    # Example:
    #
    # "10 Subjects"
    #       ↓
    # "10_subjects"
    # ------------------------------------------------------

    folder_name = (
        experiment_name
        .lower()
        .replace(" ", "_")
    )


    experiment_dir = os.path.join(
        SHALLOW_CONVNET_SPLIT_DIR,
        folder_name
    )


    os.makedirs(
        experiment_dir,
        exist_ok=True
    )


    # ------------------------------------------------------
    # Save data arrays
    # ------------------------------------------------------

    np.save(
        os.path.join(
            experiment_dir,
            "X_train.npy"
        ),
        X_train
    )

    np.save(
        os.path.join(
            experiment_dir,
            "y_train.npy"
        ),
        y_train
    )


    np.save(
        os.path.join(
            experiment_dir,
            "X_val.npy"
        ),
        X_val
    )

    np.save(
        os.path.join(
            experiment_dir,
            "y_val.npy"
        ),
        y_val
    )


    np.save(
        os.path.join(
            experiment_dir,
            "X_test.npy"
        ),
        X_test
    )

    np.save(
        os.path.join(
            experiment_dir,
            "y_test.npy"
        ),
        y_test
    )


    # ------------------------------------------------------
    # Save test subject IDs
    # ------------------------------------------------------

    np.save(
        os.path.join(
            experiment_dir,
            "test_subject_ids.npy"
        ),
        test_subject_ids
    )


    # ------------------------------------------------------
    # Save normalization statistics
    # ------------------------------------------------------

    np.save(
        os.path.join(
            experiment_dir,
            "channel_mean.npy"
        ),
        channel_mean
    )

    np.save(
        os.path.join(
            experiment_dir,
            "channel_std.npy"
        ),
        channel_std
    )


    print(
        f"\nSaved experiment data to:\n"
        f"{experiment_dir}"
    )

# %%
# ==========================================================
# CELL 8 — CREATE PYTORCH DATALOADERS
# ==========================================================

def create_dataloaders(
    X_train,
    y_train,
    X_val,
    y_val,
    X_test,
    y_test,
    batch_size=BATCH_SIZE
):

    # ======================================================
    # CONVERT NUMPY ARRAYS TO TENSORS
    # ======================================================

    X_train_tensor = torch.from_numpy(
        X_train
    ).float()

    y_train_tensor = torch.from_numpy(
        y_train
    ).long()


    X_val_tensor = torch.from_numpy(
        X_val
    ).float()

    y_val_tensor = torch.from_numpy(
        y_val
    ).long()


    X_test_tensor = torch.from_numpy(
        X_test
    ).float()

    y_test_tensor = torch.from_numpy(
        y_test
    ).long()


    # ======================================================
    # CREATE DATASETS
    # ======================================================

    train_dataset = TensorDataset(
        X_train_tensor,
        y_train_tensor
    )

    val_dataset = TensorDataset(
        X_val_tensor,
        y_val_tensor
    )

    test_dataset = TensorDataset(
        X_test_tensor,
        y_test_tensor
    )


    # ======================================================
    # CREATE DATALOADERS
    # ======================================================

    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=0
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=0
    )

    test_loader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=0
    )


    return (
        train_loader,
        val_loader,
        test_loader
    )

# %%
# ==========================================================
# CELL 9 — CREATE EEGNET MODEL
# ==========================================================

def create_shallow_convnet(
    n_channels,
    n_times,
    sfreq
):

    model = ShallowFBCSPNet(
        n_chans=n_channels,
        n_outputs=N_CLASSES,
        n_times=n_times,
        sfreq=sfreq
    )

    model = model.to(DEVICE)

    return model

# %%
# ==========================================================
# CELL 10 — TRAIN EEGNET
# ==========================================================

def train_model(
    model,
    train_loader,
    val_loader,
    num_epochs=NUM_EPOCHS,
    learning_rate=LEARNING_RATE
):

    # ======================================================
    # LOSS AND OPTIMIZER
    # ======================================================

    criterion = nn.CrossEntropyLoss()

    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=learning_rate
    )


    # ======================================================
    # TRAINING HISTORY
    # ======================================================

    history = {
        "train_loss": [],
        "val_loss": [],
        "train_accuracy": [],
        "val_accuracy": []
    }


    # ======================================================
    # BEST MODEL TRACKING
    # ======================================================

    best_val_accuracy = 0.0
    best_epoch = 0
    best_model_state = None


    # ======================================================
    # TRAINING LOOP
    # ======================================================

    for epoch in range(num_epochs):

        # ==================================================
        # TRAINING PHASE
        # ==================================================

        model.train()

        train_loss = 0.0
        train_correct = 0
        train_total = 0


        for X_batch, y_batch in train_loader:

            X_batch = X_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)


            # ----------------------------------------------
            # Clear previous gradients
            # ----------------------------------------------

            optimizer.zero_grad()


            # ----------------------------------------------
            # Forward pass
            # ----------------------------------------------

            outputs = model(X_batch)


            # ----------------------------------------------
            # Calculate loss
            # ----------------------------------------------

            loss = criterion(
                outputs,
                y_batch
            )


            # ----------------------------------------------
            # Backpropagation
            # ----------------------------------------------

            loss.backward()


            # ----------------------------------------------
            # Update model weights
            # ----------------------------------------------

            optimizer.step()


            # ----------------------------------------------
            # Accumulate loss
            # ----------------------------------------------

            train_loss += (
                loss.item()
                * X_batch.size(0)
            )


            # ----------------------------------------------
            # Predictions
            # ----------------------------------------------

            predictions = outputs.argmax(
                dim=1
            )


            train_correct += (
                predictions == y_batch
            ).sum().item()

            train_total += y_batch.size(0)


        # ==================================================
        # TRAINING METRICS
        # ==================================================

        train_loss /= train_total

        train_accuracy = (
            train_correct
            / train_total
        )


        # ==================================================
        # VALIDATION PHASE
        # ==================================================

        model.eval()

        val_loss = 0.0
        val_correct = 0
        val_total = 0


        with torch.no_grad():

            for X_batch, y_batch in val_loader:

                X_batch = X_batch.to(DEVICE)
                y_batch = y_batch.to(DEVICE)


                # ------------------------------------------
                # Forward pass
                # ------------------------------------------

                outputs = model(X_batch)


                # ------------------------------------------
                # Validation loss
                # ------------------------------------------

                loss = criterion(
                    outputs,
                    y_batch
                )


                val_loss += (
                    loss.item()
                    * X_batch.size(0)
                )


                # ------------------------------------------
                # Predictions
                # ------------------------------------------

                predictions = outputs.argmax(
                    dim=1
                )


                val_correct += (
                    predictions == y_batch
                ).sum().item()

                val_total += y_batch.size(0)


        # ==================================================
        # VALIDATION METRICS
        # ==================================================

        val_loss /= val_total

        val_accuracy = (
            val_correct
            / val_total
        )


        # ==================================================
        # SAVE HISTORY
        # ==================================================

        history["train_loss"].append(
            train_loss
        )

        history["val_loss"].append(
            val_loss
        )

        history["train_accuracy"].append(
            train_accuracy
        )

        history["val_accuracy"].append(
            val_accuracy
        )


        # ==================================================
        # SAVE BEST MODEL
        # ==================================================

        if val_accuracy > best_val_accuracy:

            best_val_accuracy = val_accuracy
            best_epoch = epoch + 1

            best_model_state = {
                key: value.detach().cpu().clone()
                for key, value
                in model.state_dict().items()
            }


        # ==================================================
        # PRINT PROGRESS
        # ==================================================

        print(
            f"Epoch [{epoch + 1:03d}/{num_epochs}] | "
            f"Train Loss: {train_loss:.4f} | "
            f"Val Loss: {val_loss:.4f} | "
            f"Train Acc: {train_accuracy:.4f} | "
            f"Val Acc: {val_accuracy:.4f}"
        )


    # ======================================================
    # RESTORE BEST MODEL
    # ======================================================

    model.load_state_dict(
        best_model_state
    )


    print("\n" + "=" * 60)

    print(
        f"Best Validation Accuracy: "
        f"{best_val_accuracy:.4f}"
    )

    print(
        f"Best Epoch: "
        f"{best_epoch}"
    )

    print("=" * 60)


    return (
        model,
        history,
        best_val_accuracy,
        best_epoch
    )

# %%
# ==========================================================
# CELL 11 — EVALUATE SHALLOW CONVNET
# ==========================================================

def evaluate_model(
    model,
    test_loader,
    test_subject_ids
):

    model.eval()


    # ======================================================
    # STORE ALL TRUE LABELS AND PREDICTIONS
    # ======================================================

    all_true = []
    all_predictions = []


    # ======================================================
    # TESTING
    # ======================================================

    with torch.no_grad():

        for X_batch, y_batch in test_loader:

            X_batch = X_batch.to(DEVICE)
            y_batch = y_batch.to(DEVICE)


            # ----------------------------------------------
            # Forward pass
            # ----------------------------------------------

            outputs = model(X_batch)


            # ----------------------------------------------
            # Predicted class
            # ----------------------------------------------

            predictions = outputs.argmax(
                dim=1
            )


            # ----------------------------------------------
            # Move results back to CPU
            # ----------------------------------------------

            all_true.extend(
                y_batch.cpu().numpy()
            )

            all_predictions.extend(
                predictions.cpu().numpy()
            )


    # ======================================================
    # CONVERT TO NUMPY ARRAYS
    # ======================================================

    all_true = np.array(
        all_true
    )

    all_predictions = np.array(
        all_predictions
    )


    # ======================================================
    # OVERALL TEST ACCURACY
    # ======================================================

    overall_accuracy = accuracy_score(
        all_true,
        all_predictions
    )


    # ======================================================
    # CLASSIFICATION REPORT
    # ======================================================

    report_text = classification_report(
        all_true,
        all_predictions,
        target_names=[
            "Rest",
            "Left",
            "Right"
        ],
        digits=4,
        zero_division=0
    )


    # ======================================================
    # CONFUSION MATRIX
    # ======================================================

    confusion = confusion_matrix(
        all_true,
        all_predictions
    )


    # ======================================================
    # SUBJECT-WISE ACCURACY
    # ======================================================

    subject_accuracies = {}


    for subject in np.unique(
        test_subject_ids
    ):

        subject_mask = (
            test_subject_ids == subject
        )


        subject_true = all_true[
            subject_mask
        ]

        subject_predictions = all_predictions[
            subject_mask
        ]


        subject_accuracy = accuracy_score(
            subject_true,
            subject_predictions
        )


        subject_accuracies[
            subject
        ] = float(
            subject_accuracy
        )


    # ======================================================
    # PRINT RESULTS
    # ======================================================

    print("\n" + "=" * 60)
    print("TEST RESULTS")
    print("=" * 60)


    print(
        f"\nOverall Accuracy: "
        f"{overall_accuracy:.4f}"
    )


    print(
        "\nClassification Report:\n"
    )

    print(
        report_text
    )


    print(
        "Confusion Matrix:\n"
    )

    print(
        confusion
    )


    print(
        "\nSubject-wise Accuracy:"
    )


    for subject, accuracy in (
        subject_accuracies.items()
    ):

        print(
            f"{subject}: "
            f"{accuracy:.4f}"
        )


    return (
        overall_accuracy,
        report_text,
        confusion,
        subject_accuracies
    )

# %%
# ==========================================================
# CELL 12 — SAVE EXPERIMENT RESULTS
# ==========================================================

def save_experiment_results(
    experiment_name,
    overall_accuracy,
    report_text,
    confusion,
    subject_accuracies
):

    # ------------------------------------------------------
    # Example:
    #
    # "10 Subjects"
    #       ↓
    # "10_subjects"
    # ------------------------------------------------------

    folder_name = (
        experiment_name
        .lower()
        .replace(" ", "_")
    )


    experiment_dir = os.path.join(
        SHALLOW_CONVNET_RESULT_DIR,
        folder_name
    )


    os.makedirs(
        experiment_dir,
        exist_ok=True
    )


    # ======================================================
    # 1. SAVE CLASSIFICATION REPORT
    #
    # precision
    # recall
    # F1-score
    # support
    # ======================================================

    report_path = os.path.join(
        experiment_dir,
        "classification_report.txt"
    )


    with open(
        report_path,
        "w"
    ) as file:

        file.write(
            report_text
        )


    # ======================================================
    # 2. SAVE CONFUSION MATRIX
    # ======================================================

    confusion_path = os.path.join(
        experiment_dir,
        "confusion_matrix.npy"
    )


    np.save(
        confusion_path,
        confusion
    )


    # ======================================================
    # 3. SAVE OVERALL + SUBJECT-WISE ACCURACY
    # ======================================================

    accuracy_results = {

        "overall_accuracy": float(
            overall_accuracy
        ),

        "subject_wise_accuracy": {
            subject: float(accuracy)
            for subject, accuracy
            in subject_accuracies.items()
        }
    }


    accuracy_path = os.path.join(
        experiment_dir,
        "accuracy_results.json"
    )


    with open(
        accuracy_path,
        "w"
    ) as file:

        json.dump(
            accuracy_results,
            file,
            indent=4
        )


    # ======================================================
    # PRINT SAVING SUMMARY
    # ======================================================

    print("\n" + "=" * 60)

    print(
        f"Results saved for: "
        f"{experiment_name}"
    )

    print(
        f"Location:\n"
        f"{experiment_dir}"
    )

    print("=" * 60)

# %%
# ==========================================================
# CELL 13 — SAVE SHALLOW CONVNET MODEL
# ==========================================================

def save_model_weights(
    model,
    experiment_name,
    best_epoch,
    best_val_accuracy
):

    folder_name = (
        experiment_name
        .lower()
        .replace(" ", "_")
    )

    experiment_dir = os.path.join(
        MODEL_DIR,
        folder_name
    )

    os.makedirs(
        experiment_dir,
        exist_ok=True
    )

    model_path = os.path.join(
        experiment_dir,
        "best_model.pth"
    )

    torch.save(
        {
            "model_state_dict": model.state_dict(),
            "best_epoch": best_epoch,
            "best_val_accuracy": best_val_accuracy,
            "n_channels": N_CHANNELS,
            "n_times": N_TIMES,
            "n_classes": N_CLASSES,
            "sfreq": 160
        },
        model_path
    )

    print(
        f"Model saved to:\n{model_path}"
    )

# %%
# ==========================================================
# CELL 14 — RUN REMAINING SHALLOW CONVNET EXPERIMENTS
# ==========================================================

import gc


experiment_summary = {}


EXPERIMENTS_TO_RUN = [
    "10 Subjects",
    "20 Subjects",
    "50 Subjects",
    "109 Subjects"
]


for EXPERIMENT_NAME in EXPERIMENTS_TO_RUN:

    random.seed(SEED)
    np.random.seed(SEED)
    torch.manual_seed(SEED)

    print("\n\n")
    print("=" * 70)
    print(f"STARTING EXPERIMENT: {EXPERIMENT_NAME}")
    print("=" * 70)


    # ======================================================
    # 1. GET EXPERIMENT CONFIGURATION
    # ======================================================

    experiment = EXPERIMENTS[
        EXPERIMENT_NAME
    ]


    # ======================================================
    # 2. PREPARE DATA
    # ======================================================

    (
        X_train,
        y_train,
        X_val,
        y_val,
        X_test,
        y_test,
        test_subject_ids,
        train_subjects,
        val_subjects,
        test_subjects

    ) = prepare_experiment_data(

        subject_data,

        experiment["train"],

        experiment["test"]
    )


    # ======================================================
    # 3. NORMALIZE DATA
    # ======================================================

    (
        X_train,
        X_val,
        X_test,
        channel_mean,
        channel_std

    ) = normalize_data(

        X_train,
        X_val,
        X_test
    )


    # ======================================================
    # 4. SAVE PREPARED DATA
    # ======================================================

    save_experiment_data(

        EXPERIMENT_NAME,

        X_train,
        y_train,

        X_val,
        y_val,

        X_test,
        y_test,

        test_subject_ids,

        channel_mean,
        channel_std
    )


    # ======================================================
    # 5. CREATE DATALOADERS
    # ======================================================

    (
        train_loader,
        val_loader,
        test_loader

    ) = create_dataloaders(

        X_train,
        y_train,

        X_val,
        y_val,

        X_test,
        y_test
    )


    # ======================================================
    # 6. CREATE A FRESH EEGNET
    # ======================================================
    N_CHANNELS = X_train.shape[1]
    N_TIMES = X_train.shape[2]
    model = create_shallow_convnet(

        n_channels=N_CHANNELS,

        n_times=N_TIMES,

        sfreq=160
    )


    # ======================================================
    # 7. TRAIN
    # ======================================================

    (
        model,
        history,
        best_val_accuracy,
        best_epoch

    ) = train_model(

        model=model,

        train_loader=train_loader,

        val_loader=val_loader,

        num_epochs=NUM_EPOCHS,

        learning_rate=LEARNING_RATE
    )


    # ======================================================
    # 8. EVALUATE
    # ======================================================

    (
        overall_accuracy,
        report_text,
        confusion,
        subject_accuracies

    ) = evaluate_model(

        model=model,

        test_loader=test_loader,

        test_subject_ids=test_subject_ids
    )


    # ======================================================
    # 9. SAVE RESULTS
    # ======================================================

    save_experiment_results(

        experiment_name=EXPERIMENT_NAME,

        overall_accuracy=overall_accuracy,

        report_text=report_text,

        confusion=confusion,

        subject_accuracies=subject_accuracies
    )


    # ======================================================
    # 10. SAVE BEST MODEL
    # ======================================================

    save_model_weights(

        model=model,

        experiment_name=EXPERIMENT_NAME,

        best_epoch=best_epoch,

        best_val_accuracy=best_val_accuracy
    )


    # ======================================================
    # 11. STORE SMALL SUMMARY IN MEMORY
    # ======================================================

    experiment_summary[
        EXPERIMENT_NAME
    ] = {

        "overall_accuracy": float(
            overall_accuracy
        ),

        "best_val_accuracy": float(
            best_val_accuracy
        ),

        "best_epoch": int(
            best_epoch
        )
    }


    # ======================================================
    # 12. DELETE LARGE OBJECTS
    # ======================================================

    del X_train
    del y_train

    del X_val
    del y_val

    del X_test
    del y_test

    del test_subject_ids

    del channel_mean
    del channel_std

    del train_loader
    del val_loader
    del test_loader

    del model
    del history 


    # ======================================================
    # 13. FORCE MEMORY CLEANUP
    # ======================================================

    gc.collect()

    if torch.backends.mps.is_available():
        torch.mps.empty_cache()


    print("\n" + "=" * 70)
    print(f"COMPLETED: {EXPERIMENT_NAME}")
    print("=" * 70)
# Out:
# ======================================================================
# STARTING EXPERIMENT: 10 Subjects
# ======================================================================
#
# ============================================================
# SUBJECT SPLIT
# ============================================================
# Training subjects   : 7
# Validation subjects : 1
# Test subjects       : 2
#
# Validation subjects:
# ['S004']
#
# Test subjects:
# ['S009', 'S010']
#
# Data shapes:
# X_train: (630, 64, 641)
# X_val  : (90, 64, 641)
# X_test : (180, 64, 641)
#
# Saved experiment data to:
# /Users/prajwalnara/Documents/EEG-motor-imagery/data/shallow_convnet_splits/10_subjects
# Epoch [001/100] | Train Loss: 1.7276 | Val Loss: 1.0877 | Train Acc: 0.3571 | Val Acc: 0.4667
# Epoch [002/100] | Train Loss: 1.3270 | Val Loss: 0.9703 | Train Acc: 0.4619 | Val Acc: 0.5000
# Epoch [003/100] | Train Loss: 1.2008 | Val Loss: 0.8985 | Train Acc: 0.5286 | Val Acc: 0.5778
# Epoch [004/100] | Train Loss: 0.9872 | Val Loss: 1.2219 | Train Acc: 0.5921 | Val Acc: 0.5000
# Epoch [005/100] | Train Loss: 0.8655 | Val Loss: 0.8435 | Train Acc: 0.6286 | Val Acc: 0.5778
# Epoch [006/100] | Train Loss: 0.8361 | Val Loss: 1.2348 | Train Acc: 0.6302 | Val Acc: 0.5000
# Epoch [007/100] | Train Loss: 0.7500 | Val Loss: 1.1007 | Train Acc: 0.7032 | Val Acc: 0.5333
# Epoch [008/100] | Train Loss: 0.6784 | Val Loss: 0.9376 | Train Acc: 0.7127 | Val Acc: 0.6000
# Epoch [009/100] | Train Loss: 0.5814 | Val Loss: 0.9333 | Train Acc: 0.7778 | Val Acc: 0.5667
# Epoch [010/100] | Train Loss: 0.5065 | Val Loss: 1.0073 | Train Acc: 0.8095 | Val Acc: 0.5111
# Epoch [011/100] | Train Loss: 0.4941 | Val Loss: 0.9916 | Train Acc: 0.8175 | Val Acc: 0.5444
# Epoch [012/100] | Train Loss: 0.4173 | Val Loss: 1.0042 | Train Acc: 0.8571 | Val Acc: 0.5222
# Epoch [013/100] | Train Loss: 0.4230 | Val Loss: 1.0461 | Train Acc: 0.8492 | Val Acc: 0.5444
# Epoch [014/100] | Train Loss: 0.3690 | Val Loss: 1.1636 | Train Acc: 0.8778 | Val Acc: 0.5444
# Epoch [015/100] | Train Loss: 0.3055 | Val Loss: 0.9218 | Train Acc: 0.8968 | Val Acc: 0.5444
# Epoch [016/100] | Train Loss: 0.2755 | Val Loss: 1.0163 | Train Acc: 0.8984 | Val Acc: 0.5333
# Epoch [017/100] | Train Loss: 0.2337 | Val Loss: 1.0501 | Train Acc: 0.9381 | Val Acc: 0.5556
# Epoch [018/100] | Train Loss: 0.2235 | Val Loss: 0.9242 | Train Acc: 0.9397 | Val Acc: 0.5333
# Epoch [019/100] | Train Loss: 0.2016 | Val Loss: 1.0397 | Train Acc: 0.9476 | Val Acc: 0.5556
# Epoch [020/100] | Train Loss: 0.1736 | Val Loss: 0.9718 | Train Acc: 0.9524 | Val Acc: 0.5444
# Epoch [021/100] | Train Loss: 0.1711 | Val Loss: 0.9978 | Train Acc: 0.9492 | Val Acc: 0.5000
# Epoch [022/100] | Train Loss: 0.1529 | Val Loss: 0.8479 | Train Acc: 0.9667 | Val Acc: 0.6111
# Epoch [023/100] | Train Loss: 0.1399 | Val Loss: 0.9268 | Train Acc: 0.9651 | Val Acc: 0.5444
# Epoch [024/100] | Train Loss: 0.1416 | Val Loss: 1.1273 | Train Acc: 0.9714 | Val Acc: 0.5556
# Epoch [025/100] | Train Loss: 0.1392 | Val Loss: 0.9647 | Train Acc: 0.9619 | Val Acc: 0.6444
# Epoch [026/100] | Train Loss: 0.1281 | Val Loss: 0.9742 | Train Acc: 0.9635 | Val Acc: 0.6111
# Epoch [027/100] | Train Loss: 0.1072 | Val Loss: 1.0267 | Train Acc: 0.9714 | Val Acc: 0.5111
# Epoch [028/100] | Train Loss: 0.1091 | Val Loss: 1.1505 | Train Acc: 0.9746 | Val Acc: 0.5444
# Epoch [029/100] | Train Loss: 0.0934 | Val Loss: 1.2990 | Train Acc: 0.9841 | Val Acc: 0.5556
# Epoch [030/100] | Train Loss: 0.0963 | Val Loss: 1.2393 | Train Acc: 0.9762 | Val Acc: 0.5444
# Epoch [031/100] | Train Loss: 0.0908 | Val Loss: 1.0534 | Train Acc: 0.9778 | Val Acc: 0.5444
# Epoch [032/100] | Train Loss: 0.0964 | Val Loss: 1.1929 | Train Acc: 0.9746 | Val Acc: 0.5333
# Epoch [033/100] | Train Loss: 0.0654 | Val Loss: 1.1361 | Train Acc: 0.9889 | Val Acc: 0.5889
# Epoch [034/100] | Train Loss: 0.0610 | Val Loss: 1.0395 | Train Acc: 0.9873 | Val Acc: 0.6000
# Epoch [035/100] | Train Loss: 0.0435 | Val Loss: 1.0314 | Train Acc: 0.9952 | Val Acc: 0.6000
# Epoch [036/100] | Train Loss: 0.0495 | Val Loss: 1.1719 | Train Acc: 0.9905 | Val Acc: 0.5333
# Epoch [037/100] | Train Loss: 0.0558 | Val Loss: 1.0676 | Train Acc: 0.9889 | Val Acc: 0.5556
# Epoch [038/100] | Train Loss: 0.0834 | Val Loss: 1.3416 | Train Acc: 0.9778 | Val Acc: 0.5222
# Epoch [039/100] | Train Loss: 0.0836 | Val Loss: 1.1293 | Train Acc: 0.9746 | Val Acc: 0.5444
# Epoch [040/100] | Train Loss: 0.0703 | Val Loss: 1.1792 | Train Acc: 0.9857 | Val Acc: 0.6333
# Epoch [041/100] | Train Loss: 0.0556 | Val Loss: 1.2487 | Train Acc: 0.9905 | Val Acc: 0.5889
# Epoch [042/100] | Train Loss: 0.0418 | Val Loss: 1.0641 | Train Acc: 0.9921 | Val Acc: 0.5778
# Epoch [043/100] | Train Loss: 0.0273 | Val Loss: 1.4325 | Train Acc: 0.9968 | Val Acc: 0.5111
# Epoch [044/100] | Train Loss: 0.0363 | Val Loss: 1.2361 | Train Acc: 0.9952 | Val Acc: 0.5222
# Epoch [045/100] | Train Loss: 0.0453 | Val Loss: 1.6116 | Train Acc: 0.9873 | Val Acc: 0.5000
# Epoch [046/100] | Train Loss: 0.0730 | Val Loss: 1.2761 | Train Acc: 0.9810 | Val Acc: 0.5222
# Epoch [047/100] | Train Loss: 0.0865 | Val Loss: 1.2095 | Train Acc: 0.9762 | Val Acc: 0.5333
# Epoch [048/100] | Train Loss: 0.0864 | Val Loss: 1.2998 | Train Acc: 0.9746 | Val Acc: 0.5444
# Epoch [049/100] | Train Loss: 0.0653 | Val Loss: 1.2293 | Train Acc: 0.9825 | Val Acc: 0.5111
# Epoch [050/100] | Train Loss: 0.0469 | Val Loss: 1.4560 | Train Acc: 0.9905 | Val Acc: 0.4778
# Epoch [051/100] | Train Loss: 0.0418 | Val Loss: 1.3463 | Train Acc: 0.9921 | Val Acc: 0.4778
# Epoch [052/100] | Train Loss: 0.0468 | Val Loss: 1.1671 | Train Acc: 0.9905 | Val Acc: 0.6111
# Epoch [053/100] | Train Loss: 0.0485 | Val Loss: 1.3416 | Train Acc: 0.9889 | Val Acc: 0.5000
# Epoch [054/100] | Train Loss: 0.1661 | Val Loss: 1.2998 | Train Acc: 0.9460 | Val Acc: 0.4667
# Epoch [055/100] | Train Loss: 0.0909 | Val Loss: 1.2371 | Train Acc: 0.9825 | Val Acc: 0.5556
# Epoch [056/100] | Train Loss: 0.0884 | Val Loss: 1.1846 | Train Acc: 0.9683 | Val Acc: 0.5111
# Epoch [057/100] | Train Loss: 0.0686 | Val Loss: 1.3769 | Train Acc: 0.9778 | Val Acc: 0.5222
# Epoch [058/100] | Train Loss: 0.1582 | Val Loss: 1.2566 | Train Acc: 0.9635 | Val Acc: 0.5889
# Epoch [059/100] | Train Loss: 0.0510 | Val Loss: 1.4576 | Train Acc: 0.9873 | Val Acc: 0.5556
# Epoch [060/100] | Train Loss: 0.0736 | Val Loss: 1.3984 | Train Acc: 0.9794 | Val Acc: 0.5556
# Epoch [061/100] | Train Loss: 0.0528 | Val Loss: 1.3480 | Train Acc: 0.9857 | Val Acc: 0.5444
# Epoch [062/100] | Train Loss: 0.0341 | Val Loss: 1.5085 | Train Acc: 0.9921 | Val Acc: 0.5111
# Epoch [063/100] | Train Loss: 0.0271 | Val Loss: 1.3283 | Train Acc: 0.9952 | Val Acc: 0.5333
# Epoch [064/100] | Train Loss: 0.0445 | Val Loss: 1.4700 | Train Acc: 0.9841 | Val Acc: 0.5889
# Epoch [065/100] | Train Loss: 0.0283 | Val Loss: 1.7006 | Train Acc: 0.9937 | Val Acc: 0.4778
# Epoch [066/100] | Train Loss: 0.0210 | Val Loss: 1.4663 | Train Acc: 0.9968 | Val Acc: 0.4889
# Epoch [067/100] | Train Loss: 0.0182 | Val Loss: 1.5299 | Train Acc: 0.9952 | Val Acc: 0.4889
# Epoch [068/100] | Train Loss: 0.0177 | Val Loss: 1.3331 | Train Acc: 0.9984 | Val Acc: 0.5444
# Epoch [069/100] | Train Loss: 0.0133 | Val Loss: 1.5456 | Train Acc: 0.9968 | Val Acc: 0.5556
# Epoch [070/100] | Train Loss: 0.0225 | Val Loss: 1.7447 | Train Acc: 0.9937 | Val Acc: 0.4556
# Epoch [071/100] | Train Loss: 0.0967 | Val Loss: 1.8540 | Train Acc: 0.9714 | Val Acc: 0.4333
# Epoch [072/100] | Train Loss: 0.0887 | Val Loss: 1.6610 | Train Acc: 0.9698 | Val Acc: 0.4222
# Epoch [073/100] | Train Loss: 0.0416 | Val Loss: 1.6783 | Train Acc: 0.9937 | Val Acc: 0.4444
# Epoch [074/100] | Train Loss: 0.0302 | Val Loss: 1.5058 | Train Acc: 0.9921 | Val Acc: 0.4556
# Epoch [075/100] | Train Loss: 0.0159 | Val Loss: 1.6332 | Train Acc: 0.9984 | Val Acc: 0.5000
# Epoch [076/100] | Train Loss: 0.0129 | Val Loss: 1.5768 | Train Acc: 0.9984 | Val Acc: 0.4778
# Epoch [077/100] | Train Loss: 0.0180 | Val Loss: 1.7213 | Train Acc: 0.9968 | Val Acc: 0.5000
# Epoch [078/100] | Train Loss: 0.0118 | Val Loss: 1.6233 | Train Acc: 1.0000 | Val Acc: 0.5222
# Epoch [079/100] | Train Loss: 0.0241 | Val Loss: 1.7430 | Train Acc: 0.9937 | Val Acc: 0.5000
# Epoch [080/100] | Train Loss: 0.0153 | Val Loss: 1.6570 | Train Acc: 0.9968 | Val Acc: 0.4889
# Epoch [081/100] | Train Loss: 0.0077 | Val Loss: 1.5492 | Train Acc: 1.0000 | Val Acc: 0.4889
# Epoch [082/100] | Train Loss: 0.0091 | Val Loss: 1.5630 | Train Acc: 1.0000 | Val Acc: 0.5111
# Epoch [083/100] | Train Loss: 0.0081 | Val Loss: 1.5411 | Train Acc: 1.0000 | Val Acc: 0.5333
# Epoch [084/100] | Train Loss: 0.0076 | Val Loss: 1.5296 | Train Acc: 1.0000 | Val Acc: 0.4667
# Epoch [085/100] | Train Loss: 0.0056 | Val Loss: 1.5712 | Train Acc: 1.0000 | Val Acc: 0.5000
# Epoch [086/100] | Train Loss: 0.0047 | Val Loss: 1.6411 | Train Acc: 1.0000 | Val Acc: 0.4667
# Epoch [087/100] | Train Loss: 0.0038 | Val Loss: 1.6647 | Train Acc: 1.0000 | Val Acc: 0.5222
# Epoch [088/100] | Train Loss: 0.0047 | Val Loss: 1.7055 | Train Acc: 1.0000 | Val Acc: 0.5222
# Epoch [089/100] | Train Loss: 0.0039 | Val Loss: 1.7528 | Train Acc: 1.0000 | Val Acc: 0.5111
# Epoch [090/100] | Train Loss: 0.0047 | Val Loss: 1.6294 | Train Acc: 1.0000 | Val Acc: 0.5333
# Epoch [091/100] | Train Loss: 0.0046 | Val Loss: 1.7705 | Train Acc: 1.0000 | Val Acc: 0.5222
# Epoch [092/100] | Train Loss: 0.0053 | Val Loss: 1.5497 | Train Acc: 1.0000 | Val Acc: 0.5222
# Epoch [093/100] | Train Loss: 0.0045 | Val Loss: 1.4965 | Train Acc: 1.0000 | Val Acc: 0.5333
# Epoch [094/100] | Train Loss: 0.0034 | Val Loss: 1.4900 | Train Acc: 1.0000 | Val Acc: 0.5444
# Epoch [095/100] | Train Loss: 0.0036 | Val Loss: 1.5640 | Train Acc: 1.0000 | Val Acc: 0.5444
# Epoch [096/100] | Train Loss: 0.0027 | Val Loss: 1.7187 | Train Acc: 1.0000 | Val Acc: 0.5111
# Epoch [097/100] | Train Loss: 0.0035 | Val Loss: 1.7186 | Train Acc: 1.0000 | Val Acc: 0.5556
# Epoch [098/100] | Train Loss: 0.0046 | Val Loss: 1.5416 | Train Acc: 1.0000 | Val Acc: 0.5444
# Epoch [099/100] | Train Loss: 0.0222 | Val Loss: 1.4544 | Train Acc: 0.9937 | Val Acc: 0.5444
# Epoch [100/100] | Train Loss: 0.0680 | Val Loss: 2.0598 | Train Acc: 0.9794 | Val Acc: 0.4556
#
# ============================================================
# Best Validation Accuracy: 0.6444
# Best Epoch: 25
# ============================================================
#
# ============================================================
# TEST RESULTS
# ============================================================
#
# Overall Accuracy: 0.4667
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         Rest     0.5267    0.7667    0.6244        90
#         Left     0.4545    0.1042    0.1695        48
#        Right     0.2632    0.2381    0.2500        42
#
#     accuracy                         0.4667       180
#    macro avg     0.4148    0.3696    0.3480       180
# weighted avg     0.4460    0.4667    0.4157       180
#
# Confusion Matrix:
#
# [[69  4 17]
#  [32  5 11]
#  [30  2 10]]
#
# Subject-wise Accuracy:
# S009: 0.5000
# S010: 0.4333
#
# ============================================================
# Results saved for: 10 Subjects
# Location:
# /Users/prajwalnara/Documents/EEG-motor-imagery/results/shallow_convnet_results/10_subjects
# ============================================================
# Model saved to:
# /Users/prajwalnara/Documents/EEG-motor-imagery/models/shallow_convnet/10_subjects/best_model.pth
#
# ======================================================================
# COMPLETED: 10 Subjects
# ======================================================================
#
#
#
# ======================================================================
# STARTING EXPERIMENT: 20 Subjects
# ======================================================================
#
# ============================================================
# SUBJECT SPLIT
# ============================================================
# Training subjects   : 15
# Validation subjects : 2
# Test subjects       : 3
#
# Validation subjects:
# ['S013', 'S017']
#
# Test subjects:
# ['S018', 'S019', 'S020']
#
# Data shapes:
# X_train: (1350, 64, 641)
# X_val  : (180, 64, 641)
# X_test : (270, 64, 641)
#
# Saved experiment data to:
# /Users/prajwalnara/Documents/EEG-motor-imagery/data/shallow_convnet_splits/20_subjects
# Epoch [001/100] | Train Loss: 1.6643 | Val Loss: 1.0167 | Train Acc: 0.3867 | Val Acc: 0.4944
# Epoch [002/100] | Train Loss: 1.3719 | Val Loss: 1.0555 | Train Acc: 0.4630 | Val Acc: 0.4833
# Epoch [003/100] | Train Loss: 1.2314 | Val Loss: 1.2471 | Train Acc: 0.5037 | Val Acc: 0.5167
# Epoch [004/100] | Train Loss: 1.1730 | Val Loss: 1.1703 | Train Acc: 0.5400 | Val Acc: 0.5333
# Epoch [005/100] | Train Loss: 1.0510 | Val Loss: 1.1210 | Train Acc: 0.5593 | Val Acc: 0.5333
# Epoch [006/100] | Train Loss: 0.9935 | Val Loss: 1.1354 | Train Acc: 0.5800 | Val Acc: 0.5056
# Epoch [007/100] | Train Loss: 0.9068 | Val Loss: 1.2287 | Train Acc: 0.6200 | Val Acc: 0.5444
# Epoch [008/100] | Train Loss: 0.8535 | Val Loss: 1.0247 | Train Acc: 0.6356 | Val Acc: 0.5389
# Epoch [009/100] | Train Loss: 0.8158 | Val Loss: 1.4919 | Train Acc: 0.6726 | Val Acc: 0.5000
# Epoch [010/100] | Train Loss: 0.7531 | Val Loss: 2.2342 | Train Acc: 0.7044 | Val Acc: 0.3389
# Epoch [011/100] | Train Loss: 0.8136 | Val Loss: 1.2034 | Train Acc: 0.6852 | Val Acc: 0.5500
# Epoch [012/100] | Train Loss: 0.7265 | Val Loss: 1.5237 | Train Acc: 0.7000 | Val Acc: 0.4944
# Epoch [013/100] | Train Loss: 0.6732 | Val Loss: 1.9636 | Train Acc: 0.7378 | Val Acc: 0.5111
# Epoch [014/100] | Train Loss: 0.6371 | Val Loss: 1.0726 | Train Acc: 0.7496 | Val Acc: 0.5278
# Epoch [015/100] | Train Loss: 0.6798 | Val Loss: 1.0783 | Train Acc: 0.7526 | Val Acc: 0.5500
# Epoch [016/100] | Train Loss: 0.6532 | Val Loss: 1.1244 | Train Acc: 0.7659 | Val Acc: 0.5611
# Epoch [017/100] | Train Loss: 0.5754 | Val Loss: 2.0712 | Train Acc: 0.7756 | Val Acc: 0.5333
# Epoch [018/100] | Train Loss: 0.5131 | Val Loss: 1.1196 | Train Acc: 0.8089 | Val Acc: 0.5222
# Epoch [019/100] | Train Loss: 0.4695 | Val Loss: 1.3304 | Train Acc: 0.8319 | Val Acc: 0.4611
# Epoch [020/100] | Train Loss: 0.5112 | Val Loss: 2.2437 | Train Acc: 0.8252 | Val Acc: 0.3556
# Epoch [021/100] | Train Loss: 0.4876 | Val Loss: 1.6206 | Train Acc: 0.8193 | Val Acc: 0.5111
# Epoch [022/100] | Train Loss: 0.4859 | Val Loss: 1.5674 | Train Acc: 0.8252 | Val Acc: 0.4500
# Epoch [023/100] | Train Loss: 0.4887 | Val Loss: 1.3250 | Train Acc: 0.8267 | Val Acc: 0.4278
# Epoch [024/100] | Train Loss: 0.3933 | Val Loss: 1.4562 | Train Acc: 0.8607 | Val Acc: 0.5167
# Epoch [025/100] | Train Loss: 0.4391 | Val Loss: 1.7156 | Train Acc: 0.8481 | Val Acc: 0.5167
# Epoch [026/100] | Train Loss: 0.3980 | Val Loss: 1.5951 | Train Acc: 0.8607 | Val Acc: 0.4389
# Epoch [027/100] | Train Loss: 0.4140 | Val Loss: 1.5016 | Train Acc: 0.8548 | Val Acc: 0.4833
# Epoch [028/100] | Train Loss: 0.3520 | Val Loss: 1.8232 | Train Acc: 0.8719 | Val Acc: 0.5611
# Epoch [029/100] | Train Loss: 0.3526 | Val Loss: 1.8330 | Train Acc: 0.8815 | Val Acc: 0.5167
# Epoch [030/100] | Train Loss: 0.3164 | Val Loss: 1.9836 | Train Acc: 0.8948 | Val Acc: 0.5278
# Epoch [031/100] | Train Loss: 0.3219 | Val Loss: 1.3049 | Train Acc: 0.8978 | Val Acc: 0.5611
# Epoch [032/100] | Train Loss: 0.3499 | Val Loss: 2.0172 | Train Acc: 0.8719 | Val Acc: 0.5222
# Epoch [033/100] | Train Loss: 0.4007 | Val Loss: 1.2874 | Train Acc: 0.8711 | Val Acc: 0.4611
# Epoch [034/100] | Train Loss: 0.3183 | Val Loss: 2.2716 | Train Acc: 0.8904 | Val Acc: 0.5167
# Epoch [035/100] | Train Loss: 0.3167 | Val Loss: 1.3076 | Train Acc: 0.8904 | Val Acc: 0.5222
# Epoch [036/100] | Train Loss: 0.2869 | Val Loss: 1.3218 | Train Acc: 0.9081 | Val Acc: 0.4556
# Epoch [037/100] | Train Loss: 0.2466 | Val Loss: 1.2978 | Train Acc: 0.9215 | Val Acc: 0.5056
# Epoch [038/100] | Train Loss: 0.2424 | Val Loss: 1.3663 | Train Acc: 0.9207 | Val Acc: 0.5556
# Epoch [039/100] | Train Loss: 0.2441 | Val Loss: 1.5459 | Train Acc: 0.9267 | Val Acc: 0.4444
# Epoch [040/100] | Train Loss: 0.2620 | Val Loss: 1.6567 | Train Acc: 0.9133 | Val Acc: 0.5222
# Epoch [041/100] | Train Loss: 0.2073 | Val Loss: 1.6040 | Train Acc: 0.9341 | Val Acc: 0.5389
# Epoch [042/100] | Train Loss: 0.2614 | Val Loss: 1.3031 | Train Acc: 0.9044 | Val Acc: 0.5556
# Epoch [043/100] | Train Loss: 0.2356 | Val Loss: 1.2786 | Train Acc: 0.9215 | Val Acc: 0.5333
# Epoch [044/100] | Train Loss: 0.2656 | Val Loss: 1.2891 | Train Acc: 0.9156 | Val Acc: 0.5167
# Epoch [045/100] | Train Loss: 0.2471 | Val Loss: 1.6682 | Train Acc: 0.9141 | Val Acc: 0.5111
# Epoch [046/100] | Train Loss: 0.2581 | Val Loss: 1.6909 | Train Acc: 0.9089 | Val Acc: 0.5500
# Epoch [047/100] | Train Loss: 0.2486 | Val Loss: 1.7395 | Train Acc: 0.9126 | Val Acc: 0.5111
# Epoch [048/100] | Train Loss: 0.2825 | Val Loss: 3.1778 | Train Acc: 0.9119 | Val Acc: 0.5167
# Epoch [049/100] | Train Loss: 0.2249 | Val Loss: 1.5037 | Train Acc: 0.9274 | Val Acc: 0.5556
# Epoch [050/100] | Train Loss: 0.2396 | Val Loss: 1.8609 | Train Acc: 0.9185 | Val Acc: 0.5556
# Epoch [051/100] | Train Loss: 0.2586 | Val Loss: 2.2369 | Train Acc: 0.9237 | Val Acc: 0.5389
# Epoch [052/100] | Train Loss: 0.2846 | Val Loss: 1.3032 | Train Acc: 0.9111 | Val Acc: 0.5444
# Epoch [053/100] | Train Loss: 0.2601 | Val Loss: 1.9287 | Train Acc: 0.9096 | Val Acc: 0.5444
# Epoch [054/100] | Train Loss: 0.2523 | Val Loss: 1.8573 | Train Acc: 0.9185 | Val Acc: 0.5444
# Epoch [055/100] | Train Loss: 0.2152 | Val Loss: 1.9321 | Train Acc: 0.9326 | Val Acc: 0.4278
# Epoch [056/100] | Train Loss: 0.1936 | Val Loss: 1.9303 | Train Acc: 0.9296 | Val Acc: 0.5444
# Epoch [057/100] | Train Loss: 0.2004 | Val Loss: 1.6177 | Train Acc: 0.9356 | Val Acc: 0.5389
# Epoch [058/100] | Train Loss: 0.2209 | Val Loss: 2.6354 | Train Acc: 0.9304 | Val Acc: 0.4778
# Epoch [059/100] | Train Loss: 0.2230 | Val Loss: 2.3876 | Train Acc: 0.9311 | Val Acc: 0.5278
# Epoch [060/100] | Train Loss: 0.2355 | Val Loss: 2.1099 | Train Acc: 0.9185 | Val Acc: 0.5167
# Epoch [061/100] | Train Loss: 0.2046 | Val Loss: 1.6419 | Train Acc: 0.9326 | Val Acc: 0.4500
# Epoch [062/100] | Train Loss: 0.1969 | Val Loss: 1.9253 | Train Acc: 0.9259 | Val Acc: 0.5278
# Epoch [063/100] | Train Loss: 0.2139 | Val Loss: 2.4939 | Train Acc: 0.9326 | Val Acc: 0.5444
# Epoch [064/100] | Train Loss: 0.2045 | Val Loss: 4.3844 | Train Acc: 0.9341 | Val Acc: 0.5111
# Epoch [065/100] | Train Loss: 0.1624 | Val Loss: 2.0471 | Train Acc: 0.9422 | Val Acc: 0.5167
# Epoch [066/100] | Train Loss: 0.1885 | Val Loss: 2.5298 | Train Acc: 0.9422 | Val Acc: 0.5111
# Epoch [067/100] | Train Loss: 0.2216 | Val Loss: 2.4757 | Train Acc: 0.9289 | Val Acc: 0.5389
# Epoch [068/100] | Train Loss: 0.2084 | Val Loss: 4.0690 | Train Acc: 0.9341 | Val Acc: 0.5111
# Epoch [069/100] | Train Loss: 0.2055 | Val Loss: 2.2130 | Train Acc: 0.9370 | Val Acc: 0.5167
# Epoch [070/100] | Train Loss: 0.1988 | Val Loss: 1.5947 | Train Acc: 0.9370 | Val Acc: 0.5000
# Epoch [071/100] | Train Loss: 0.1509 | Val Loss: 2.2088 | Train Acc: 0.9504 | Val Acc: 0.5167
# Epoch [072/100] | Train Loss: 0.1622 | Val Loss: 2.4876 | Train Acc: 0.9444 | Val Acc: 0.5222
# Epoch [073/100] | Train Loss: 0.1838 | Val Loss: 2.5866 | Train Acc: 0.9481 | Val Acc: 0.5278
# Epoch [074/100] | Train Loss: 0.1801 | Val Loss: 2.3840 | Train Acc: 0.9437 | Val Acc: 0.5278
# Epoch [075/100] | Train Loss: 0.2059 | Val Loss: 1.4717 | Train Acc: 0.9296 | Val Acc: 0.5278
# Epoch [076/100] | Train Loss: 0.1710 | Val Loss: 2.2963 | Train Acc: 0.9452 | Val Acc: 0.5333
# Epoch [077/100] | Train Loss: 0.1871 | Val Loss: 2.5261 | Train Acc: 0.9393 | Val Acc: 0.5333
# Epoch [078/100] | Train Loss: 0.1939 | Val Loss: 2.0101 | Train Acc: 0.9415 | Val Acc: 0.4889
# Epoch [079/100] | Train Loss: 0.1842 | Val Loss: 2.9365 | Train Acc: 0.9467 | Val Acc: 0.4111
# Epoch [080/100] | Train Loss: 0.1796 | Val Loss: 3.1676 | Train Acc: 0.9363 | Val Acc: 0.5389
# Epoch [081/100] | Train Loss: 0.1771 | Val Loss: 2.6153 | Train Acc: 0.9496 | Val Acc: 0.5111
# Epoch [082/100] | Train Loss: 0.2014 | Val Loss: 2.2155 | Train Acc: 0.9311 | Val Acc: 0.5278
# Epoch [083/100] | Train Loss: 0.2008 | Val Loss: 2.5406 | Train Acc: 0.9341 | Val Acc: 0.5222
# Epoch [084/100] | Train Loss: 0.2149 | Val Loss: 2.0441 | Train Acc: 0.9415 | Val Acc: 0.5278
# Epoch [085/100] | Train Loss: 0.2138 | Val Loss: 3.4401 | Train Acc: 0.9363 | Val Acc: 0.3778
# Epoch [086/100] | Train Loss: 0.1767 | Val Loss: 1.9169 | Train Acc: 0.9511 | Val Acc: 0.5611
# Epoch [087/100] | Train Loss: 0.2617 | Val Loss: 2.4319 | Train Acc: 0.9170 | Val Acc: 0.5222
# Epoch [088/100] | Train Loss: 0.1839 | Val Loss: 2.0041 | Train Acc: 0.9370 | Val Acc: 0.5333
# Epoch [089/100] | Train Loss: 0.1932 | Val Loss: 1.6484 | Train Acc: 0.9400 | Val Acc: 0.5111
# Epoch [090/100] | Train Loss: 0.2637 | Val Loss: 2.0278 | Train Acc: 0.9348 | Val Acc: 0.5111
# Epoch [091/100] | Train Loss: 0.1828 | Val Loss: 2.5175 | Train Acc: 0.9422 | Val Acc: 0.5167
# Epoch [092/100] | Train Loss: 0.1628 | Val Loss: 2.5684 | Train Acc: 0.9496 | Val Acc: 0.5444
# Epoch [093/100] | Train Loss: 0.1506 | Val Loss: 3.1527 | Train Acc: 0.9496 | Val Acc: 0.5222
# Epoch [094/100] | Train Loss: 0.1406 | Val Loss: 1.4903 | Train Acc: 0.9526 | Val Acc: 0.4889
# Epoch [095/100] | Train Loss: 0.1890 | Val Loss: 2.5405 | Train Acc: 0.9415 | Val Acc: 0.5056
# Epoch [096/100] | Train Loss: 0.1507 | Val Loss: 1.7783 | Train Acc: 0.9459 | Val Acc: 0.5444
# Epoch [097/100] | Train Loss: 0.1641 | Val Loss: 2.2043 | Train Acc: 0.9526 | Val Acc: 0.5111
# Epoch [098/100] | Train Loss: 0.1520 | Val Loss: 2.3889 | Train Acc: 0.9496 | Val Acc: 0.5389
# Epoch [099/100] | Train Loss: 0.1348 | Val Loss: 3.3843 | Train Acc: 0.9541 | Val Acc: 0.5389
# Epoch [100/100] | Train Loss: 0.1820 | Val Loss: 1.9649 | Train Acc: 0.9496 | Val Acc: 0.5167
#
# ============================================================
# Best Validation Accuracy: 0.5611
# Best Epoch: 16
# ============================================================
#
# ============================================================
# TEST RESULTS
# ============================================================
#
# Overall Accuracy: 0.4481
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         Rest     0.7010    0.5037    0.5862       135
#         Left     0.4000    0.0588    0.1026        68
#        Right     0.3006    0.7313    0.4261        67
#
#     accuracy                         0.4481       270
#    macro avg     0.4672    0.4313    0.3716       270
# weighted avg     0.5259    0.4481    0.4247       270
#
# Confusion Matrix:
#
# [[68  2 65]
#  [15  4 49]
#  [14  4 49]]
#
# Subject-wise Accuracy:
# S018: 0.3667
# S019: 0.5778
# S020: 0.4000
#
# ============================================================
# Results saved for: 20 Subjects
# Location:
# /Users/prajwalnara/Documents/EEG-motor-imagery/results/shallow_convnet_results/20_subjects
# ============================================================
# Model saved to:
# /Users/prajwalnara/Documents/EEG-motor-imagery/models/shallow_convnet/20_subjects/best_model.pth
#
# ======================================================================
# COMPLETED: 20 Subjects
# ======================================================================
#
#
#
# ======================================================================
# STARTING EXPERIMENT: 50 Subjects
# ======================================================================
#
# ============================================================
# SUBJECT SPLIT
# ============================================================
# Training subjects   : 38
# Validation subjects : 4
# Test subjects       : 8
#
# Validation subjects:
# ['S019', 'S022', 'S027', 'S030']
#
# Test subjects:
# ['S043', 'S044', 'S045', 'S046', 'S047', 'S048', 'S049', 'S050']
#
# Data shapes:
# X_train: (3415, 64, 641)
# X_val  : (360, 64, 641)
# X_test : (720, 64, 641)
#
# Saved experiment data to:
# /Users/prajwalnara/Documents/EEG-motor-imagery/data/shallow_convnet_splits/50_subjects
# Epoch [001/100] | Train Loss: 1.7352 | Val Loss: 1.3979 | Train Acc: 0.4176 | Val Acc: 0.4861
# Epoch [002/100] | Train Loss: 1.4828 | Val Loss: 1.1508 | Train Acc: 0.4758 | Val Acc: 0.5111
# Epoch [003/100] | Train Loss: 1.2960 | Val Loss: 1.0933 | Train Acc: 0.4996 | Val Acc: 0.4611
# Epoch [004/100] | Train Loss: 1.2184 | Val Loss: 1.2809 | Train Acc: 0.5151 | Val Acc: 0.4639
# Epoch [005/100] | Train Loss: 1.1247 | Val Loss: 1.0644 | Train Acc: 0.5452 | Val Acc: 0.5389
# Epoch [006/100] | Train Loss: 1.0574 | Val Loss: 0.9818 | Train Acc: 0.5769 | Val Acc: 0.5333
# Epoch [007/100] | Train Loss: 0.9901 | Val Loss: 1.0652 | Train Acc: 0.6018 | Val Acc: 0.5583
# Epoch [008/100] | Train Loss: 0.9805 | Val Loss: 0.9406 | Train Acc: 0.6158 | Val Acc: 0.5500
# Epoch [009/100] | Train Loss: 0.8989 | Val Loss: 1.1324 | Train Acc: 0.6460 | Val Acc: 0.5306
# Epoch [010/100] | Train Loss: 0.8660 | Val Loss: 0.9704 | Train Acc: 0.6574 | Val Acc: 0.5611
# Epoch [011/100] | Train Loss: 0.8585 | Val Loss: 1.1186 | Train Acc: 0.6530 | Val Acc: 0.5167
# Epoch [012/100] | Train Loss: 0.8772 | Val Loss: 0.8340 | Train Acc: 0.6583 | Val Acc: 0.6167
# Epoch [013/100] | Train Loss: 0.8294 | Val Loss: 0.9505 | Train Acc: 0.6741 | Val Acc: 0.6083
# Epoch [014/100] | Train Loss: 0.8147 | Val Loss: 0.9339 | Train Acc: 0.6802 | Val Acc: 0.5972
# Epoch [015/100] | Train Loss: 0.7261 | Val Loss: 1.0420 | Train Acc: 0.7192 | Val Acc: 0.5417
# Epoch [016/100] | Train Loss: 0.7746 | Val Loss: 1.1216 | Train Acc: 0.6987 | Val Acc: 0.5333
# Epoch [017/100] | Train Loss: 0.7885 | Val Loss: 1.2202 | Train Acc: 0.6984 | Val Acc: 0.5389
# Epoch [018/100] | Train Loss: 0.7616 | Val Loss: 0.8483 | Train Acc: 0.7075 | Val Acc: 0.6306
# Epoch [019/100] | Train Loss: 0.7077 | Val Loss: 1.0744 | Train Acc: 0.7271 | Val Acc: 0.5500
# Epoch [020/100] | Train Loss: 0.7156 | Val Loss: 0.9817 | Train Acc: 0.7233 | Val Acc: 0.5972
# Epoch [021/100] | Train Loss: 0.6962 | Val Loss: 1.0737 | Train Acc: 0.7286 | Val Acc: 0.5611
# Epoch [022/100] | Train Loss: 0.6726 | Val Loss: 1.0699 | Train Acc: 0.7417 | Val Acc: 0.5472
# Epoch [023/100] | Train Loss: 0.7249 | Val Loss: 1.3256 | Train Acc: 0.7262 | Val Acc: 0.5139
# Epoch [024/100] | Train Loss: 0.7122 | Val Loss: 1.0157 | Train Acc: 0.7344 | Val Acc: 0.5750
# Epoch [025/100] | Train Loss: 0.6598 | Val Loss: 1.1542 | Train Acc: 0.7493 | Val Acc: 0.5222
# Epoch [026/100] | Train Loss: 0.6780 | Val Loss: 1.4360 | Train Acc: 0.7376 | Val Acc: 0.5083
# Epoch [027/100] | Train Loss: 0.6420 | Val Loss: 1.0953 | Train Acc: 0.7613 | Val Acc: 0.5667
# Epoch [028/100] | Train Loss: 0.6725 | Val Loss: 0.9324 | Train Acc: 0.7531 | Val Acc: 0.6028
# Epoch [029/100] | Train Loss: 0.6306 | Val Loss: 0.9682 | Train Acc: 0.7628 | Val Acc: 0.5694
# Epoch [030/100] | Train Loss: 0.6446 | Val Loss: 1.1112 | Train Acc: 0.7564 | Val Acc: 0.5472
# Epoch [031/100] | Train Loss: 0.5850 | Val Loss: 1.2483 | Train Acc: 0.7859 | Val Acc: 0.4944
# Epoch [032/100] | Train Loss: 0.6337 | Val Loss: 0.9472 | Train Acc: 0.7690 | Val Acc: 0.6028
# Epoch [033/100] | Train Loss: 0.5934 | Val Loss: 1.2198 | Train Acc: 0.7693 | Val Acc: 0.5194
# Epoch [034/100] | Train Loss: 0.6086 | Val Loss: 1.1440 | Train Acc: 0.7792 | Val Acc: 0.5722
# Epoch [035/100] | Train Loss: 0.6214 | Val Loss: 1.2456 | Train Acc: 0.7813 | Val Acc: 0.5417
# Epoch [036/100] | Train Loss: 0.5833 | Val Loss: 1.1529 | Train Acc: 0.7742 | Val Acc: 0.5583
# Epoch [037/100] | Train Loss: 0.6032 | Val Loss: 1.0030 | Train Acc: 0.7816 | Val Acc: 0.5778
# Epoch [038/100] | Train Loss: 0.5959 | Val Loss: 1.1106 | Train Acc: 0.7848 | Val Acc: 0.5611
# Epoch [039/100] | Train Loss: 0.5656 | Val Loss: 1.1485 | Train Acc: 0.7939 | Val Acc: 0.5667
# Epoch [040/100] | Train Loss: 0.6124 | Val Loss: 0.9677 | Train Acc: 0.7789 | Val Acc: 0.6222
# Epoch [041/100] | Train Loss: 0.5364 | Val Loss: 0.9951 | Train Acc: 0.8061 | Val Acc: 0.5917
# Epoch [042/100] | Train Loss: 0.5367 | Val Loss: 1.1294 | Train Acc: 0.8064 | Val Acc: 0.5917
# Epoch [043/100] | Train Loss: 0.5707 | Val Loss: 0.9569 | Train Acc: 0.7857 | Val Acc: 0.6056
# Epoch [044/100] | Train Loss: 0.5465 | Val Loss: 1.0817 | Train Acc: 0.8061 | Val Acc: 0.5500
# Epoch [045/100] | Train Loss: 0.5318 | Val Loss: 0.9861 | Train Acc: 0.8035 | Val Acc: 0.6000
# Epoch [046/100] | Train Loss: 0.5720 | Val Loss: 1.0473 | Train Acc: 0.7941 | Val Acc: 0.5806
# Epoch [047/100] | Train Loss: 0.5715 | Val Loss: 1.0394 | Train Acc: 0.7980 | Val Acc: 0.5750
# Epoch [048/100] | Train Loss: 0.5458 | Val Loss: 1.3124 | Train Acc: 0.8029 | Val Acc: 0.5667
# Epoch [049/100] | Train Loss: 0.5441 | Val Loss: 1.1866 | Train Acc: 0.8070 | Val Acc: 0.5389
# Epoch [050/100] | Train Loss: 0.5277 | Val Loss: 1.1583 | Train Acc: 0.8158 | Val Acc: 0.5472
# Epoch [051/100] | Train Loss: 0.5335 | Val Loss: 0.9047 | Train Acc: 0.8152 | Val Acc: 0.6000
# Epoch [052/100] | Train Loss: 0.5405 | Val Loss: 1.1701 | Train Acc: 0.8117 | Val Acc: 0.5417
# Epoch [053/100] | Train Loss: 0.5334 | Val Loss: 1.0238 | Train Acc: 0.8126 | Val Acc: 0.6333
# Epoch [054/100] | Train Loss: 0.5203 | Val Loss: 1.3273 | Train Acc: 0.8149 | Val Acc: 0.5528
# Epoch [055/100] | Train Loss: 0.5508 | Val Loss: 1.0354 | Train Acc: 0.8085 | Val Acc: 0.6056
# Epoch [056/100] | Train Loss: 0.5200 | Val Loss: 1.1068 | Train Acc: 0.8167 | Val Acc: 0.5778
# Epoch [057/100] | Train Loss: 0.5303 | Val Loss: 1.0567 | Train Acc: 0.8170 | Val Acc: 0.5778
# Epoch [058/100] | Train Loss: 0.4896 | Val Loss: 1.2198 | Train Acc: 0.8214 | Val Acc: 0.5472
# Epoch [059/100] | Train Loss: 0.4834 | Val Loss: 1.3721 | Train Acc: 0.8231 | Val Acc: 0.5333
# Epoch [060/100] | Train Loss: 0.4900 | Val Loss: 1.1385 | Train Acc: 0.8199 | Val Acc: 0.5889
# Epoch [061/100] | Train Loss: 0.5004 | Val Loss: 1.0463 | Train Acc: 0.8272 | Val Acc: 0.6111
# Epoch [062/100] | Train Loss: 0.5191 | Val Loss: 0.9765 | Train Acc: 0.8246 | Val Acc: 0.6167
# Epoch [063/100] | Train Loss: 0.4807 | Val Loss: 1.1533 | Train Acc: 0.8381 | Val Acc: 0.5667
# Epoch [064/100] | Train Loss: 0.4708 | Val Loss: 1.1081 | Train Acc: 0.8264 | Val Acc: 0.5694
# Epoch [065/100] | Train Loss: 0.4799 | Val Loss: 1.0770 | Train Acc: 0.8316 | Val Acc: 0.5917
# Epoch [066/100] | Train Loss: 0.5087 | Val Loss: 1.1568 | Train Acc: 0.8299 | Val Acc: 0.5778
# Epoch [067/100] | Train Loss: 0.4918 | Val Loss: 1.1671 | Train Acc: 0.8261 | Val Acc: 0.5833
# Epoch [068/100] | Train Loss: 0.4570 | Val Loss: 1.6280 | Train Acc: 0.8387 | Val Acc: 0.5139
# Epoch [069/100] | Train Loss: 0.4634 | Val Loss: 1.3323 | Train Acc: 0.8351 | Val Acc: 0.5556
# Epoch [070/100] | Train Loss: 0.4591 | Val Loss: 1.9395 | Train Acc: 0.8381 | Val Acc: 0.5000
# Epoch [071/100] | Train Loss: 0.4708 | Val Loss: 1.1338 | Train Acc: 0.8372 | Val Acc: 0.5861
# Epoch [072/100] | Train Loss: 0.4801 | Val Loss: 1.2707 | Train Acc: 0.8322 | Val Acc: 0.5778
# Epoch [073/100] | Train Loss: 0.4698 | Val Loss: 1.7398 | Train Acc: 0.8331 | Val Acc: 0.4944
# Epoch [074/100] | Train Loss: 0.4569 | Val Loss: 1.0200 | Train Acc: 0.8337 | Val Acc: 0.6028
# Epoch [075/100] | Train Loss: 0.4572 | Val Loss: 0.9901 | Train Acc: 0.8407 | Val Acc: 0.6361
# Epoch [076/100] | Train Loss: 0.4696 | Val Loss: 1.0749 | Train Acc: 0.8381 | Val Acc: 0.6028
# Epoch [077/100] | Train Loss: 0.4712 | Val Loss: 1.0986 | Train Acc: 0.8334 | Val Acc: 0.6000
# Epoch [078/100] | Train Loss: 0.4420 | Val Loss: 0.9933 | Train Acc: 0.8454 | Val Acc: 0.6222
# Epoch [079/100] | Train Loss: 0.4533 | Val Loss: 1.0198 | Train Acc: 0.8454 | Val Acc: 0.6111
# Epoch [080/100] | Train Loss: 0.4839 | Val Loss: 1.2235 | Train Acc: 0.8340 | Val Acc: 0.5750
# Epoch [081/100] | Train Loss: 0.4233 | Val Loss: 1.1887 | Train Acc: 0.8504 | Val Acc: 0.6222
# Epoch [082/100] | Train Loss: 0.4263 | Val Loss: 1.3729 | Train Acc: 0.8515 | Val Acc: 0.5472
# Epoch [083/100] | Train Loss: 0.4052 | Val Loss: 1.1508 | Train Acc: 0.8492 | Val Acc: 0.5861
# Epoch [084/100] | Train Loss: 0.4344 | Val Loss: 1.5736 | Train Acc: 0.8428 | Val Acc: 0.5389
# Epoch [085/100] | Train Loss: 0.4235 | Val Loss: 1.0908 | Train Acc: 0.8489 | Val Acc: 0.6111
# Epoch [086/100] | Train Loss: 0.4521 | Val Loss: 1.2177 | Train Acc: 0.8378 | Val Acc: 0.5611
# Epoch [087/100] | Train Loss: 0.4433 | Val Loss: 1.0694 | Train Acc: 0.8489 | Val Acc: 0.6028
# Epoch [088/100] | Train Loss: 0.4427 | Val Loss: 1.6070 | Train Acc: 0.8439 | Val Acc: 0.5278
# Epoch [089/100] | Train Loss: 0.4345 | Val Loss: 1.1559 | Train Acc: 0.8556 | Val Acc: 0.5972
# Epoch [090/100] | Train Loss: 0.4357 | Val Loss: 1.1348 | Train Acc: 0.8466 | Val Acc: 0.5806
# Epoch [091/100] | Train Loss: 0.4500 | Val Loss: 1.2382 | Train Acc: 0.8448 | Val Acc: 0.5917
# Epoch [092/100] | Train Loss: 0.4305 | Val Loss: 0.9965 | Train Acc: 0.8527 | Val Acc: 0.6194
# Epoch [093/100] | Train Loss: 0.4301 | Val Loss: 1.1062 | Train Acc: 0.8583 | Val Acc: 0.5861
# Epoch [094/100] | Train Loss: 0.4525 | Val Loss: 1.7115 | Train Acc: 0.8387 | Val Acc: 0.5056
# Epoch [095/100] | Train Loss: 0.4304 | Val Loss: 1.4912 | Train Acc: 0.8515 | Val Acc: 0.5333
# Epoch [096/100] | Train Loss: 0.4177 | Val Loss: 1.3269 | Train Acc: 0.8571 | Val Acc: 0.5639
# Epoch [097/100] | Train Loss: 0.4373 | Val Loss: 1.6506 | Train Acc: 0.8480 | Val Acc: 0.5139
# Epoch [098/100] | Train Loss: 0.3965 | Val Loss: 1.3416 | Train Acc: 0.8536 | Val Acc: 0.5333
# Epoch [099/100] | Train Loss: 0.4044 | Val Loss: 1.3907 | Train Acc: 0.8571 | Val Acc: 0.5389
# Epoch [100/100] | Train Loss: 0.4319 | Val Loss: 1.3323 | Train Acc: 0.8521 | Val Acc: 0.5944
#
# ============================================================
# Best Validation Accuracy: 0.6361
# Best Epoch: 75
# ============================================================
#
# ============================================================
# TEST RESULTS
# ============================================================
#
# Overall Accuracy: 0.7222
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         Rest     0.7304    0.8806    0.7985       360
#         Left     0.7133    0.5847    0.6426       183
#        Right     0.7059    0.5424    0.6134       177
#
#     accuracy                         0.7222       720
#    macro avg     0.7165    0.6692    0.6848       720
# weighted avg     0.7200    0.7222    0.7134       720
#
# Confusion Matrix:
#
# [[317  19  24]
#  [ 60 107  16]
#  [ 57  24  96]]
#
# Subject-wise Accuracy:
# S043: 0.8000
# S044: 0.7444
# S045: 0.7000
# S046: 0.6778
# S047: 0.5222
# S048: 0.7889
# S049: 0.7222
# S050: 0.8222
#
# ============================================================
# Results saved for: 50 Subjects
# Location:
# /Users/prajwalnara/Documents/EEG-motor-imagery/results/shallow_convnet_results/50_subjects
# ============================================================
# Model saved to:
# /Users/prajwalnara/Documents/EEG-motor-imagery/models/shallow_convnet/50_subjects/best_model.pth
#
# ======================================================================
# COMPLETED: 50 Subjects
# ======================================================================
#
#
#
# ======================================================================
# STARTING EXPERIMENT: 109 Subjects
# ======================================================================
#
# ============================================================
# SUBJECT SPLIT
# ============================================================
# Training subjects   : 81
# Validation subjects : 9
# Test subjects       : 16
#
# Validation subjects:
# ['S003', 'S005', 'S028', 'S053', 'S056', 'S072', 'S077', 'S085', 'S091']
#
# Test subjects:
# ['S093', 'S094', 'S095', 'S096', 'S097', 'S098', 'S099', 'S101', 'S102', 'S103', 'S104', 'S105', 'S106', 'S107', 'S108', 'S109']
#
# Data shapes:
# X_train: (7253, 64, 641)
# X_val  : (810, 64, 641)
# X_test : (1422, 64, 641)
#
# Saved experiment data to:
# /Users/prajwalnara/Documents/EEG-motor-imagery/data/shallow_convnet_splits/109_subjects
# Epoch [001/100] | Train Loss: 1.8678 | Val Loss: 1.2889 | Train Acc: 0.4133 | Val Acc: 0.5049
# Epoch [002/100] | Train Loss: 1.4304 | Val Loss: 1.2576 | Train Acc: 0.4715 | Val Acc: 0.4926
# Epoch [003/100] | Train Loss: 1.3058 | Val Loss: 0.8711 | Train Acc: 0.5108 | Val Acc: 0.5901
# Epoch [004/100] | Train Loss: 1.2112 | Val Loss: 5.3472 | Train Acc: 0.5414 | Val Acc: 0.5296
# Epoch [005/100] | Train Loss: 1.2923 | Val Loss: 0.8379 | Train Acc: 0.5498 | Val Acc: 0.6284
# Epoch [006/100] | Train Loss: 1.1312 | Val Loss: 0.8810 | Train Acc: 0.5796 | Val Acc: 0.6012
# Epoch [007/100] | Train Loss: 1.1101 | Val Loss: 0.8081 | Train Acc: 0.5923 | Val Acc: 0.6259
# Epoch [008/100] | Train Loss: 0.9886 | Val Loss: 4.0539 | Train Acc: 0.6152 | Val Acc: 0.2667
# Epoch [009/100] | Train Loss: 1.0631 | Val Loss: 0.8121 | Train Acc: 0.6082 | Val Acc: 0.6198
# Epoch [010/100] | Train Loss: 1.0165 | Val Loss: 0.9203 | Train Acc: 0.6173 | Val Acc: 0.6012
# Epoch [011/100] | Train Loss: 0.9849 | Val Loss: 1.2883 | Train Acc: 0.6359 | Val Acc: 0.3506
# Epoch [012/100] | Train Loss: 0.9814 | Val Loss: 2.2589 | Train Acc: 0.6333 | Val Acc: 0.5000
# Epoch [013/100] | Train Loss: 0.9863 | Val Loss: 0.7849 | Train Acc: 0.6339 | Val Acc: 0.6593
# Epoch [014/100] | Train Loss: 0.9395 | Val Loss: 0.7753 | Train Acc: 0.6421 | Val Acc: 0.6519
# Epoch [015/100] | Train Loss: 0.9216 | Val Loss: 0.8058 | Train Acc: 0.6572 | Val Acc: 0.6667
# Epoch [016/100] | Train Loss: 0.8894 | Val Loss: 0.9396 | Train Acc: 0.6505 | Val Acc: 0.5691
# Epoch [017/100] | Train Loss: 0.8933 | Val Loss: 1.4486 | Train Acc: 0.6559 | Val Acc: 0.2444
# Epoch [018/100] | Train Loss: 0.8633 | Val Loss: 2.6927 | Train Acc: 0.6648 | Val Acc: 0.5000
# Epoch [019/100] | Train Loss: 0.8792 | Val Loss: 1.0206 | Train Acc: 0.6662 | Val Acc: 0.6136
# Epoch [020/100] | Train Loss: 0.8643 | Val Loss: 1.6352 | Train Acc: 0.6724 | Val Acc: 0.3210
# Epoch [021/100] | Train Loss: 0.8277 | Val Loss: 1.0767 | Train Acc: 0.6818 | Val Acc: 0.5370
# Epoch [022/100] | Train Loss: 0.8294 | Val Loss: 0.8393 | Train Acc: 0.6785 | Val Acc: 0.6395
# Epoch [023/100] | Train Loss: 0.8292 | Val Loss: 1.7793 | Train Acc: 0.6794 | Val Acc: 0.5000
# Epoch [024/100] | Train Loss: 0.8020 | Val Loss: 0.8097 | Train Acc: 0.6851 | Val Acc: 0.6840
# Epoch [025/100] | Train Loss: 0.8153 | Val Loss: 0.6848 | Train Acc: 0.6885 | Val Acc: 0.7025
# Epoch [026/100] | Train Loss: 0.7869 | Val Loss: 0.9113 | Train Acc: 0.6960 | Val Acc: 0.6333
# Epoch [027/100] | Train Loss: 0.7897 | Val Loss: 0.7427 | Train Acc: 0.6891 | Val Acc: 0.6741
# Epoch [028/100] | Train Loss: 0.7666 | Val Loss: 1.0239 | Train Acc: 0.6994 | Val Acc: 0.5049
# Epoch [029/100] | Train Loss: 0.7602 | Val Loss: 1.0518 | Train Acc: 0.6975 | Val Acc: 0.5000
# Epoch [030/100] | Train Loss: 0.7664 | Val Loss: 0.8485 | Train Acc: 0.6891 | Val Acc: 0.6630
# Epoch [031/100] | Train Loss: 0.7502 | Val Loss: 0.7088 | Train Acc: 0.7074 | Val Acc: 0.6753
# Epoch [032/100] | Train Loss: 0.7465 | Val Loss: 0.6830 | Train Acc: 0.7092 | Val Acc: 0.6914
# Epoch [033/100] | Train Loss: 0.7417 | Val Loss: 0.8705 | Train Acc: 0.7098 | Val Acc: 0.6494
# Epoch [034/100] | Train Loss: 0.7262 | Val Loss: 0.7263 | Train Acc: 0.7125 | Val Acc: 0.6716
# Epoch [035/100] | Train Loss: 0.7218 | Val Loss: 0.7428 | Train Acc: 0.7123 | Val Acc: 0.6556
# Epoch [036/100] | Train Loss: 0.7124 | Val Loss: 0.7619 | Train Acc: 0.7192 | Val Acc: 0.6519
# Epoch [037/100] | Train Loss: 0.7139 | Val Loss: 0.7692 | Train Acc: 0.7103 | Val Acc: 0.6716
# Epoch [038/100] | Train Loss: 0.7094 | Val Loss: 1.0056 | Train Acc: 0.7215 | Val Acc: 0.5049
# Epoch [039/100] | Train Loss: 0.6966 | Val Loss: 0.7382 | Train Acc: 0.7219 | Val Acc: 0.6840
# Epoch [040/100] | Train Loss: 0.7045 | Val Loss: 0.6935 | Train Acc: 0.7237 | Val Acc: 0.7099
# Epoch [041/100] | Train Loss: 0.6864 | Val Loss: 0.7095 | Train Acc: 0.7249 | Val Acc: 0.7037
# Epoch [042/100] | Train Loss: 0.6822 | Val Loss: 0.7170 | Train Acc: 0.7270 | Val Acc: 0.6951
# Epoch [043/100] | Train Loss: 0.6697 | Val Loss: 0.7209 | Train Acc: 0.7380 | Val Acc: 0.6889
# Epoch [044/100] | Train Loss: 0.6872 | Val Loss: 0.9112 | Train Acc: 0.7295 | Val Acc: 0.6519
# Epoch [045/100] | Train Loss: 0.6825 | Val Loss: 0.7605 | Train Acc: 0.7283 | Val Acc: 0.6506
# Epoch [046/100] | Train Loss: 0.6651 | Val Loss: 0.8699 | Train Acc: 0.7371 | Val Acc: 0.5864
# Epoch [047/100] | Train Loss: 0.6821 | Val Loss: 0.8741 | Train Acc: 0.7285 | Val Acc: 0.5753
# Epoch [048/100] | Train Loss: 0.6771 | Val Loss: 0.7928 | Train Acc: 0.7325 | Val Acc: 0.6704
# Epoch [049/100] | Train Loss: 0.6452 | Val Loss: 0.7949 | Train Acc: 0.7437 | Val Acc: 0.6395
# Epoch [050/100] | Train Loss: 0.6623 | Val Loss: 0.8406 | Train Acc: 0.7376 | Val Acc: 0.6543
# Epoch [051/100] | Train Loss: 0.6691 | Val Loss: 1.0131 | Train Acc: 0.7318 | Val Acc: 0.6037
# Epoch [052/100] | Train Loss: 0.6556 | Val Loss: 0.7768 | Train Acc: 0.7408 | Val Acc: 0.6593
# Epoch [053/100] | Train Loss: 0.6470 | Val Loss: 0.7021 | Train Acc: 0.7394 | Val Acc: 0.6975
# Epoch [054/100] | Train Loss: 0.6460 | Val Loss: 1.4417 | Train Acc: 0.7445 | Val Acc: 0.4012
# Epoch [055/100] | Train Loss: 0.6455 | Val Loss: 1.0232 | Train Acc: 0.7379 | Val Acc: 0.5012
# Epoch [056/100] | Train Loss: 0.6292 | Val Loss: 1.0037 | Train Acc: 0.7404 | Val Acc: 0.5642
# Epoch [057/100] | Train Loss: 0.6400 | Val Loss: 0.7650 | Train Acc: 0.7413 | Val Acc: 0.6519
# Epoch [058/100] | Train Loss: 0.6433 | Val Loss: 0.9088 | Train Acc: 0.7426 | Val Acc: 0.5580
# Epoch [059/100] | Train Loss: 0.6293 | Val Loss: 0.7486 | Train Acc: 0.7459 | Val Acc: 0.6864
# Epoch [060/100] | Train Loss: 0.6327 | Val Loss: 1.0857 | Train Acc: 0.7422 | Val Acc: 0.5012
# Epoch [061/100] | Train Loss: 0.6370 | Val Loss: 0.8575 | Train Acc: 0.7434 | Val Acc: 0.6457
# Epoch [062/100] | Train Loss: 0.6115 | Val Loss: 1.0502 | Train Acc: 0.7605 | Val Acc: 0.5000
# Epoch [063/100] | Train Loss: 0.6176 | Val Loss: 0.8633 | Train Acc: 0.7543 | Val Acc: 0.6630
# Epoch [064/100] | Train Loss: 0.6208 | Val Loss: 1.2504 | Train Acc: 0.7543 | Val Acc: 0.6074
# Epoch [065/100] | Train Loss: 0.6177 | Val Loss: 1.1846 | Train Acc: 0.7536 | Val Acc: 0.2667
# Epoch [066/100] | Train Loss: 0.6107 | Val Loss: 0.8750 | Train Acc: 0.7582 | Val Acc: 0.6333
# Epoch [067/100] | Train Loss: 0.6047 | Val Loss: 0.9480 | Train Acc: 0.7593 | Val Acc: 0.6247
# Epoch [068/100] | Train Loss: 0.6113 | Val Loss: 0.7719 | Train Acc: 0.7532 | Val Acc: 0.6543
# Epoch [069/100] | Train Loss: 0.6102 | Val Loss: 0.9815 | Train Acc: 0.7536 | Val Acc: 0.6531
# Epoch [070/100] | Train Loss: 0.6048 | Val Loss: 1.0081 | Train Acc: 0.7540 | Val Acc: 0.4593
# Epoch [071/100] | Train Loss: 0.6136 | Val Loss: 0.7972 | Train Acc: 0.7516 | Val Acc: 0.6765
# Epoch [072/100] | Train Loss: 0.6041 | Val Loss: 0.9559 | Train Acc: 0.7622 | Val Acc: 0.6049
# Epoch [073/100] | Train Loss: 0.5943 | Val Loss: 1.0539 | Train Acc: 0.7671 | Val Acc: 0.6556
# Epoch [074/100] | Train Loss: 0.5908 | Val Loss: 0.7368 | Train Acc: 0.7604 | Val Acc: 0.6679
# Epoch [075/100] | Train Loss: 0.5825 | Val Loss: 0.7925 | Train Acc: 0.7673 | Val Acc: 0.6543
# Epoch [076/100] | Train Loss: 0.6173 | Val Loss: 0.9523 | Train Acc: 0.7572 | Val Acc: 0.6148
# Epoch [077/100] | Train Loss: 0.5810 | Val Loss: 0.9955 | Train Acc: 0.7688 | Val Acc: 0.5012
# Epoch [078/100] | Train Loss: 0.5839 | Val Loss: 0.9136 | Train Acc: 0.7667 | Val Acc: 0.5556
# Epoch [079/100] | Train Loss: 0.5812 | Val Loss: 1.1629 | Train Acc: 0.7740 | Val Acc: 0.6222
# Epoch [080/100] | Train Loss: 0.5867 | Val Loss: 1.0556 | Train Acc: 0.7686 | Val Acc: 0.5062
# Epoch [081/100] | Train Loss: 0.5805 | Val Loss: 1.1414 | Train Acc: 0.7637 | Val Acc: 0.5877
# Epoch [082/100] | Train Loss: 0.5877 | Val Loss: 0.7684 | Train Acc: 0.7662 | Val Acc: 0.6802
# Epoch [083/100] | Train Loss: 0.5769 | Val Loss: 0.8235 | Train Acc: 0.7684 | Val Acc: 0.6568
# Epoch [084/100] | Train Loss: 0.5692 | Val Loss: 0.9811 | Train Acc: 0.7728 | Val Acc: 0.5506
# Epoch [085/100] | Train Loss: 0.5691 | Val Loss: 0.8842 | Train Acc: 0.7711 | Val Acc: 0.6765
# Epoch [086/100] | Train Loss: 0.5644 | Val Loss: 1.0231 | Train Acc: 0.7747 | Val Acc: 0.5049
# Epoch [087/100] | Train Loss: 0.5691 | Val Loss: 0.8265 | Train Acc: 0.7722 | Val Acc: 0.6790
# Epoch [088/100] | Train Loss: 0.5646 | Val Loss: 0.9469 | Train Acc: 0.7729 | Val Acc: 0.5457
# Epoch [089/100] | Train Loss: 0.5795 | Val Loss: 1.2175 | Train Acc: 0.7713 | Val Acc: 0.5000
# Epoch [090/100] | Train Loss: 0.5836 | Val Loss: 0.9454 | Train Acc: 0.7671 | Val Acc: 0.6296
# Epoch [091/100] | Train Loss: 0.5605 | Val Loss: 0.9861 | Train Acc: 0.7790 | Val Acc: 0.6852
# Epoch [092/100] | Train Loss: 0.5506 | Val Loss: 1.0637 | Train Acc: 0.7834 | Val Acc: 0.5000
# Epoch [093/100] | Train Loss: 0.5512 | Val Loss: 1.1316 | Train Acc: 0.7791 | Val Acc: 0.5889
# Epoch [094/100] | Train Loss: 0.5639 | Val Loss: 1.0689 | Train Acc: 0.7773 | Val Acc: 0.5037
# Epoch [095/100] | Train Loss: 0.5448 | Val Loss: 1.0256 | Train Acc: 0.7766 | Val Acc: 0.5074
# Epoch [096/100] | Train Loss: 0.5595 | Val Loss: 0.8570 | Train Acc: 0.7735 | Val Acc: 0.6704
# Epoch [097/100] | Train Loss: 0.5721 | Val Loss: 0.8079 | Train Acc: 0.7720 | Val Acc: 0.6383
# Epoch [098/100] | Train Loss: 0.5605 | Val Loss: 0.8823 | Train Acc: 0.7826 | Val Acc: 0.6790
# Epoch [099/100] | Train Loss: 0.5482 | Val Loss: 0.7564 | Train Acc: 0.7798 | Val Acc: 0.6988
# Epoch [100/100] | Train Loss: 0.5518 | Val Loss: 1.0087 | Train Acc: 0.7804 | Val Acc: 0.5025
#
# ============================================================
# Best Validation Accuracy: 0.7099
# Best Epoch: 40
# ============================================================
#
# ============================================================
# TEST RESULTS
# ============================================================
#
# Overall Accuracy: 0.6266
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         Rest     0.7468    0.7289    0.7377       712
#         Left     0.5675    0.4568    0.5062       359
#        Right     0.4749    0.5926    0.5272       351
#
#     accuracy                         0.6266      1422
#    macro avg     0.5964    0.5928    0.5904      1422
# weighted avg     0.6344    0.6266    0.6273      1422
#
# Confusion Matrix:
#
# [[519  67 126]
#  [ 91 164 104]
#  [ 85  58 208]]
#
# Subject-wise Accuracy:
# S093: 0.6556
# S094: 0.8333
# S095: 0.6222
# S096: 0.6444
# S097: 0.6444
# S098: 0.6778
# S099: 0.5111
# S101: 0.6556
# S102: 0.6778
# S103: 0.6333
# S104: 0.6860
# S105: 0.6889
# S106: 0.6667
# S107: 0.5667
# S108: 0.5921
# S109: 0.2667
#
# ============================================================
# Results saved for: 109 Subjects
# Location:
# /Users/prajwalnara/Documents/EEG-motor-imagery/results/shallow_convnet_results/109_subjects
# ============================================================
# Model saved to:
# /Users/prajwalnara/Documents/EEG-motor-imagery/models/shallow_convnet/109_subjects/best_model.pth
#
# ======================================================================
# COMPLETED: 109 Subjects
# ======================================================================
