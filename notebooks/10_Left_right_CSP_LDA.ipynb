# %%
import os
import warnings
import numpy as np
import mne
import joblib

from mne.decoding import CSP

# %%
# ==========================================================
# CONFIGURATION
# ==========================================================

EPOCH_DIR = "/Users/prajwalnara/Documents/EEG-motor-imagery/data/processed/epochs"

FEATURE_DIR = "/Users/prajwalnara/Documents/EEG-motor-imagery/data/features/CSP_leftright"

SUBJECT_EXPERIMENTS = [10, 20, 50, 109]

RUNS = ["R04", "R08", "R12"]

LEFT_EVENT = 2
RIGHT_EVENT = 3

N_COMPONENTS = 8

TRAIN_RATIO = 0.70

EXPECTED_TIMEPOINTS = 641

os.makedirs(FEATURE_DIR, exist_ok=True)

# %%
def load_subject_epochs(subject_list):

    """
    Loads R04, R08 and R12 epochs for each subject.

    Subjects having inconsistent epoch lengths are skipped.
    """

    subject_epochs = {}

    skipped_subjects = []

    for subject in subject_list:

        subject_folder = os.path.join(EPOCH_DIR, subject)

        epochs_list = []

        valid_subject = True

        for run in RUNS:

            file_path = os.path.join(
                subject_folder,
                f"{subject}{run}_epo.fif"
            )

            if not os.path.exists(file_path):
                continue

            try:

                epochs = mne.read_epochs(
                    file_path,
                    preload=True,
                    verbose=False
                )

                # -------------------------------------------------
                # Validate epoch length
                # -------------------------------------------------

                if epochs.get_data().shape[-1] != EXPECTED_TIMEPOINTS:

                    raise ValueError(
                        f"{run} has {epochs.get_data().shape[-1]} samples "
                        f"(expected {EXPECTED_TIMEPOINTS})"
                    )

                epochs_list.append(epochs)

            except Exception as e:

                print(f"Skipping {subject} ({run}) : {e}")

                valid_subject = False

                break

        if not valid_subject:
            skipped_subjects.append(subject)
            continue

        if len(epochs_list) == 0:
            skipped_subjects.append(subject)
            continue

        # Suppress harmless annotation warning
        with warnings.catch_warnings():

            warnings.filterwarnings(
                "ignore",
                message="Concatenation of Annotations within Epochs is not supported yet.*"
            )

            subject_epochs[subject] = mne.concatenate_epochs(
                epochs_list
            )

    print()

    print("=" * 60)

    print(f"Loaded Subjects : {len(subject_epochs)}")

    print(f"Skipped Subjects: {len(skipped_subjects)}")

    if len(skipped_subjects):

        print(skipped_subjects)

    print("=" * 60)

    return subject_epochs

# %%
def extract_left_right(subject_epochs):

    """
    Extract only Left (2) and Right (3) imagery epochs.

    Returns:
        subject_data = {
            subject : (X, y)
        }
    """

    subject_data = {}

    for subject, epochs in subject_epochs.items():

        # Keep only Left and Right
        mask = np.isin(
            epochs.events[:, -1],
            [LEFT_EVENT, RIGHT_EVENT]
        )

        selected_epochs = epochs[mask]

        X = selected_epochs.get_data()

        y = selected_epochs.events[:, -1]

        # Convert labels
        # Left  -> 0
        # Right -> 1
        y = np.where(y == LEFT_EVENT, 0, 1)

        # Skip if one class is missing
        if len(np.unique(y)) != 2:

            print(f"Skipping {subject}: only one class present")

            continue

        subject_data[subject] = (X, y)

    return subject_data

# %%
def prepare_train_test(subject_data):

    subjects = sorted(subject_data.keys())

    n_subjects = len(subjects)

    n_train = int(TRAIN_RATIO * n_subjects)

    train_subjects = subjects[:n_train]

    test_subjects = subjects[n_train:]

    X_train = []
    y_train = []

    X_test = []
    y_test = []

    # ------------------------
    # Training
    # ------------------------

    for subject in train_subjects:

        X, y = subject_data[subject]

        X_train.append(X)

        y_train.append(y)

    # ------------------------
    # Testing
    # ------------------------

    for subject in test_subjects:

        X, y = subject_data[subject]

        X_test.append(X)

        y_test.append(y)

    X_train = np.concatenate(X_train, axis=0)

    y_train = np.concatenate(y_train, axis=0)

    X_test = np.concatenate(X_test, axis=0)

    y_test = np.concatenate(y_test, axis=0)

    return (

        X_train,
        y_train,

        X_test,
        y_test,

        train_subjects,
        test_subjects

    )

# %%
def extract_csp_features(
    X_train,
    y_train,
    X_test
):
    """
    Learn CSP filters from training data
    and transform both train and test.
    """

    csp = CSP(
        n_components=N_COMPONENTS,
        reg=None,
        log=True,
        norm_trace=False
    )

    X_train_csp = csp.fit_transform(
        X_train,
        y_train
    )

    X_test_csp = csp.transform(
        X_test
    )

    return X_train_csp, X_test_csp, csp

# %%
def save_features(
    experiment_name,
    X_train,
    y_train,
    X_test,
    y_test,
    csp
):

    save_dir = os.path.join(
        FEATURE_DIR,
        experiment_name
    )

    os.makedirs(
        save_dir,
        exist_ok=True
    )

    np.save(
        os.path.join(save_dir, "X_train.npy"),
        X_train
    )

    np.save(
        os.path.join(save_dir, "y_train.npy"),
        y_train
    )

    np.save(
        os.path.join(save_dir, "X_test.npy"),
        X_test
    )

    np.save(
        os.path.join(save_dir, "y_test.npy"),
        y_test
    )

    # Save trained CSP object
    joblib.dump(
        csp,
        os.path.join(save_dir, "csp.pkl")
    )

    print(f"Saved -> {save_dir}")

# %%
# ==========================================================
# VALIDATE SUBJECT EPOCH LENGTHS
# ==========================================================

EXPECTED_TIMEPOINTS = 641


def get_valid_subjects(subjects):

    valid_subjects = []
    skipped_subjects = []

    print("\nChecking epoch lengths...")

    for subject in subjects:

        try:
            # Load only this subject
            subject_epochs = load_subject_epochs([subject])

            # Extract the subject's epochs from the returned structure
            epochs = subject_epochs[subject]

            X = epochs.get_data()

            print(
                f"{subject}: "
                f"shape={X.shape}"
            )

            # ----------------------------------------------
            # Check time dimension
            # ----------------------------------------------

            if X.shape[-1] != EXPECTED_TIMEPOINTS:

                print(
                    f"  SKIPPED {subject}: "
                    f"got {X.shape[-1]} samples, "
                    f"expected {EXPECTED_TIMEPOINTS}"
                )

                skipped_subjects.append(subject)

                continue

            valid_subjects.append(subject)

        except Exception as e:

            print(
                f"  SKIPPED {subject}: {e}"
            )

            skipped_subjects.append(subject)

    print("\n" + "-" * 60)

    print(
        f"Valid Subjects   : "
        f"{len(valid_subjects)}/{len(subjects)}"
    )

    print(
        f"Skipped Subjects : "
        f"{len(skipped_subjects)}"
    )

    if skipped_subjects:

        print(
            "Skipped List     :",
            skipped_subjects
        )

    print("-" * 60)

    return valid_subjects, skipped_subjects

# %%
for n_subjects in SUBJECT_EXPERIMENTS:

    print("\n" + "=" * 70)
    print(f"Processing {n_subjects} Subjects")
    print("=" * 70)

    subjects = [
        f"S{i:03d}"
        for i in range(1, n_subjects + 1)
    ]

    # ======================================================
    # STEP 1: CHECK EPOCH LENGTHS
    # ======================================================

    valid_subjects, skipped_subjects = get_valid_subjects(
        subjects
    )

    if len(valid_subjects) == 0:

        print(
            f"No valid subjects for "
            f"{n_subjects}-subject experiment."
        )

        continue

    # ======================================================
    # STEP 2: LOAD ONLY VALID SUBJECTS
    # ======================================================

    subject_epochs = load_subject_epochs(
        valid_subjects
    )

    # ======================================================
    # STEP 3: EXTRACT LEFT / RIGHT
    # ======================================================

    subject_data = extract_left_right(
        subject_epochs
    )

    # ======================================================
    # STEP 4: SUBJECT-LEVEL TRAIN / TEST SPLIT
    # ======================================================

    (
        X_train,
        y_train,
        X_test,
        y_test,
        train_subjects,
        test_subjects
    ) = prepare_train_test(
        subject_data
    )

    # ======================================================
    # STEP 5: CSP
    # ======================================================

    X_train_csp, X_test_csp, csp = extract_csp_features(
        X_train,
        y_train,
        X_test
    )

    # ======================================================
    # STEP 6: SAVE FEATURES
    # ======================================================

    save_features(
        f"{n_subjects}subjects",
        X_train_csp,
        y_train,
        X_test_csp,
        y_test,
        csp
    )

    # ======================================================
    # SUMMARY
    # ======================================================

    print("\n" + "-" * 60)

    print(f"Requested Subjects : {n_subjects}")
    print(f"Valid Subjects     : {len(valid_subjects)}")
    print(f"Skipped Subjects   : {len(skipped_subjects)}")

    if skipped_subjects:
        print(f"Skipped List       : {skipped_subjects}")

    print()

    print("Train Subjects :", len(train_subjects))
    print("Test Subjects  :", len(test_subjects))

    print()

    print("Train Epochs :", len(y_train))
    print("Test Epochs  :", len(y_test))

    print()

    print("Train Left  :", np.sum(y_train == 0))
    print("Train Right :", np.sum(y_train == 1))

    print()

    print("Test Left   :", np.sum(y_test == 0))
    print("Test Right  :", np.sum(y_test == 1))

    print()

    print(
        "Feature Shape (Train):",
        X_train_csp.shape
    )

    print(
        "Feature Shape (Test) :",
        X_test_csp.shape
    )

    print("-" * 60)
# Out:
# ======================================================================
# Processing 10 Subjects
# ======================================================================
#
# Checking epoch lengths...
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S001: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S002: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S003: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S004: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S005: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S006: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S007: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S008: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S009: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S010: shape=(90, 64, 641)
#
# ------------------------------------------------------------
# Valid Subjects   : 10/10
# Skipped Subjects : 0
# ------------------------------------------------------------
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 10
# Skipped Subjects: 0
# ============================================================
# Computing rank from data with rank=None
#     Using tolerance 0.00084 (2.2e-16 eps * 64 dim * 5.9e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Saved -> /Users/prajwalnara/Documents/EEG-motor-imagery/data/features/CSP_leftright/10subjects
#
# ------------------------------------------------------------
# Requested Subjects : 10
# Valid Subjects     : 10
# Skipped Subjects   : 0
#
# Train Subjects : 7
# Test Subjects  : 3
#
# Train Epochs : 315
# Test Epochs  : 135
#
# Train Left  : 160
# Train Right : 155
#
# Test Left   : 70
# Test Right  : 65
#
# Feature Shape (Train): (315, 8)
# Feature Shape (Test) : (135, 8)
# ------------------------------------------------------------
#
# ======================================================================
# Processing 20 Subjects
# ======================================================================
#
# Checking epoch lengths...
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S001: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S002: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S003: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S004: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S005: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S006: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S007: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S008: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S009: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S010: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S011: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S012: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S013: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S014: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S015: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S016: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S017: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S018: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S019: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S020: shape=(90, 64, 641)
#
# ------------------------------------------------------------
# Valid Subjects   : 20/20
# Skipped Subjects : 0
# ------------------------------------------------------------
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 20
# Skipped Subjects: 0
# ============================================================
# Computing rank from data with rank=None
#     Using tolerance 0.0013 (2.2e-16 eps * 64 dim * 9.1e+10  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Saved -> /Users/prajwalnara/Documents/EEG-motor-imagery/data/features/CSP_leftright/20subjects
#
# ------------------------------------------------------------
# Requested Subjects : 20
# Valid Subjects     : 20
# Skipped Subjects   : 0
#
# Train Subjects : 14
# Test Subjects  : 6
#
# Train Epochs : 630
# Test Epochs  : 270
#
# Train Left  : 319
# Train Right : 311
#
# Test Left   : 136
# Test Right  : 134
#
# Feature Shape (Train): (630, 8)
# Feature Shape (Test) : (270, 8)
# ------------------------------------------------------------
#
# ======================================================================
# Processing 50 Subjects
# ======================================================================
#
# Checking epoch lengths...
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S001: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S002: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S003: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S004: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S005: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S006: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S007: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S008: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S009: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S010: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S011: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S012: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S013: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S014: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S015: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S016: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S017: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S018: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S019: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S020: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S021: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S022: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S023: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S024: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S025: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S026: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S027: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S028: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S029: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S030: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S031: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S032: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S033: shape=(90, 64, 641)
# Not setting metadata
# 88 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S034: shape=(88, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S035: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S036: shape=(90, 64, 641)
# Not setting metadata
# 88 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S037: shape=(88, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S038: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S039: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S040: shape=(90, 64, 641)
# Not setting metadata
# 89 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S041: shape=(89, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S042: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S043: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S044: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S045: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S046: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S047: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S048: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S049: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S050: shape=(90, 64, 641)
#
# ------------------------------------------------------------
# Valid Subjects   : 50/50
# Skipped Subjects : 0
# ------------------------------------------------------------
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 88 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 88 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 89 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 50
# Skipped Subjects: 0
# ============================================================
# Computing rank from data with rank=None
#     Using tolerance 0.002 (2.2e-16 eps * 64 dim * 1.4e+11  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Saved -> /Users/prajwalnara/Documents/EEG-motor-imagery/data/features/CSP_leftright/50subjects
#
# ------------------------------------------------------------
# Requested Subjects : 50
# Valid Subjects     : 50
# Skipped Subjects   : 0
#
# Train Subjects : 35
# Test Subjects  : 15
#
# Train Epochs : 1573
# Test Epochs  : 672
#
# Train Left  : 792
# Train Right : 781
#
# Test Left   : 340
# Test Right  : 332
#
# Feature Shape (Train): (1573, 8)
# Feature Shape (Test) : (672, 8)
# ------------------------------------------------------------
#
# ======================================================================
# Processing 109 Subjects
# ======================================================================
#
# Checking epoch lengths...
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S001: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S002: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S003: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S004: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S005: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S006: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S007: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S008: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S009: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S010: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S011: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S012: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S013: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S014: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S015: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S016: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S017: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S018: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S019: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S020: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S021: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S022: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S023: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S024: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S025: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S026: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S027: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S028: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S029: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S030: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S031: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S032: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S033: shape=(90, 64, 641)
# Not setting metadata
# 88 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S034: shape=(88, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S035: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S036: shape=(90, 64, 641)
# Not setting metadata
# 88 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S037: shape=(88, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S038: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S039: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S040: shape=(90, 64, 641)
# Not setting metadata
# 89 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S041: shape=(89, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S042: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S043: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S044: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S045: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S046: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S047: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S048: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S049: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S050: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S051: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S052: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S053: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S054: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S055: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S056: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S057: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S058: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S059: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S060: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# ...
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S085: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S086: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S087: shape=(90, 64, 641)
# Skipping S088 (R04) : R04 has 513 samples (expected 641)
#
# ============================================================
# Loaded Subjects : 0
# Skipped Subjects: 1
# ['S088']
# ============================================================
#   SKIPPED S088: 'S088'
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S089: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S090: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S091: shape=(90, 64, 641)
# Skipping S092 (R04) : R04 has 513 samples (expected 641)
#
# ============================================================
# Loaded Subjects : 0
# Skipped Subjects: 1
# ['S092']
# ============================================================
#   SKIPPED S092: 'S092'
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S093: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S094: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S095: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S096: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S097: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S098: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S099: shape=(90, 64, 641)
# Skipping S100 (R04) : R04 has 513 samples (expected 641)
#
# ============================================================
# Loaded Subjects : 0
# Skipped Subjects: 1
# ['S100']
# ============================================================
#   SKIPPED S100: 'S100'
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S101: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S102: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S103: shape=(90, 64, 641)
# Not setting metadata
# 86 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S104: shape=(86, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S105: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S106: shape=(90, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S107: shape=(90, 64, 641)
# Not setting metadata
# 76 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S108: shape=(76, 64, 641)
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 1
# Skipped Subjects: 0
# ============================================================
# S109: shape=(90, 64, 641)
#
# ------------------------------------------------------------
# Valid Subjects   : 106/109
# Skipped Subjects : 3
# Skipped List     : ['S088', 'S092', 'S100']
# ------------------------------------------------------------
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 88 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 88 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 89 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 68 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 86 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
# Not setting metadata
# 76 matching events found
# No baseline correction applied
# Not setting metadata
# 90 matching events found
# No baseline correction applied
#
# ============================================================
# Loaded Subjects : 106
# Skipped Subjects: 0
# ============================================================
# Computing rank from data with rank=None
#     Using tolerance 0.0033 (2.2e-16 eps * 64 dim * 2.3e+11  max singular value)
#     Estimated rank (data): 64
#     data: rank 64 computed from 64 data channels with 0 projectors
# Reducing data rank from 64 -> 64
# Estimating class=0 covariance using EMPIRICAL
# Done.
# Estimating class=1 covariance using EMPIRICAL
# Done.
# Saved -> /Users/prajwalnara/Documents/EEG-motor-imagery/data/features/CSP_leftright/109subjects
#
# ------------------------------------------------------------
# Requested Subjects : 109
# Valid Subjects     : 106
# Skipped Subjects   : 3
# Skipped List       : ['S088', 'S092', 'S100']
#
# Train Subjects : 74
# Test Subjects  : 32
#
# Train Epochs : 3320
# Test Epochs  : 1418
#
# Train Left  : 1678
# Train Right : 1642
#
# Test Left   : 712
# Test Right  : 706
#
# Feature Shape (Train): (3320, 8)
# Feature Shape (Test) : (1418, 8)
# ------------------------------------------------------------

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)

# %%
def train_evaluate_lda(
    X_train,
    y_train,
    X_test,
    y_test
):

    # Create LDA classifier
    lda = LinearDiscriminantAnalysis()

    # Train
    lda.fit(X_train, y_train)

    # Predictions
    y_train_pred = lda.predict(X_train)
    y_test_pred = lda.predict(X_test)

    # Accuracies
    train_accuracy = accuracy_score(
        y_train,
        y_train_pred
    )

    test_accuracy = accuracy_score(
        y_test,
        y_test_pred
    )

    # Test confusion matrix
    cm = confusion_matrix(
        y_test,
        y_test_pred
    )

    return (
        lda,
        y_train_pred,
        y_test_pred,
        train_accuracy,
        test_accuracy,
        cm
    )

# %%
lda_results = {}

for n_subjects in SUBJECT_EXPERIMENTS:

    print("\n" + "=" * 70)
    print(f"LDA Experiment : {n_subjects} Subjects")
    print("=" * 70)

    experiment_dir = os.path.join(
        FEATURE_DIR,
        f"{n_subjects}subjects"
    )

    # ----------------------------------
    # Load CSP features
    # ----------------------------------

    X_train_csp = np.load(
        os.path.join(experiment_dir, "X_train.npy")
    )

    y_train = np.load(
        os.path.join(experiment_dir, "y_train.npy")
    )

    X_test_csp = np.load(
        os.path.join(experiment_dir, "X_test.npy")
    )

    y_test = np.load(
        os.path.join(experiment_dir, "y_test.npy")
    )

    # ----------------------------------
    # Train and evaluate LDA
    # ----------------------------------

    (
        lda,
        y_train_pred,
        y_test_pred,
        train_accuracy,
        test_accuracy,
        cm
    ) = train_evaluate_lda(
        X_train_csp,
        y_train,
        X_test_csp,
        y_test
    )

    # ----------------------------------
    # Save results
    # ----------------------------------

    lda_results[n_subjects] = {
        "train_accuracy": train_accuracy,
        "test_accuracy": test_accuracy,
        "confusion_matrix": cm,
        "y_train_pred": y_train_pred,
        "y_test_pred": y_test_pred
    }

    # ----------------------------------
    # Print results
    # ----------------------------------

    print(
        f"Train Accuracy : {train_accuracy:.4f} "
        f"({train_accuracy * 100:.2f}%)"
    )

    print(
        f"Test Accuracy  : {test_accuracy:.4f} "
        f"({test_accuracy * 100:.2f}%)"
    )

    print(
        f"Accuracy Gap   : "
        f"{(train_accuracy - test_accuracy) * 100:.2f}%"
    )

    print("\nTest Confusion Matrix")
    print(cm)

    print("\nTest Classification Report")

    print(
        classification_report(
            y_test,
            y_test_pred,
            target_names=["Left", "Right"],
            digits=4
        )
    )
# Out:
# ======================================================================
# LDA Experiment : 10 Subjects
# ======================================================================
# Train Accuracy : 0.6571 (65.71%)
# Test Accuracy  : 0.5111 (51.11%)
# Accuracy Gap   : 14.60%
#
# Test Confusion Matrix
# [[58 12]
#  [54 11]]
#
# Test Classification Report
#               precision    recall  f1-score   support
#
#         Left     0.5179    0.8286    0.6374        70
#        Right     0.4783    0.1692    0.2500        65
#
#     accuracy                         0.5111       135
#    macro avg     0.4981    0.4989    0.4437       135
# weighted avg     0.4988    0.5111    0.4509       135
#
#
# ======================================================================
# LDA Experiment : 20 Subjects
# ======================================================================
# Train Accuracy : 0.5492 (54.92%)
# Test Accuracy  : 0.5074 (50.74%)
# Accuracy Gap   : 4.18%
#
# Test Confusion Matrix
# [[66 70]
#  [63 71]]
#
# Test Classification Report
#               precision    recall  f1-score   support
#
#         Left     0.5116    0.4853    0.4981       136
#        Right     0.5035    0.5299    0.5164       134
#
#     accuracy                         0.5074       270
#    macro avg     0.5076    0.5076    0.5072       270
# weighted avg     0.5076    0.5074    0.5072       270
#
#
# ======================================================================
# LDA Experiment : 50 Subjects
# ======================================================================
# Train Accuracy : 0.5289 (52.89%)
# Test Accuracy  : 0.5149 (51.49%)
# Accuracy Gap   : 1.40%
#
# Test Confusion Matrix
# [[157 183]
#  [143 189]]
#
# Test Classification Report
#               precision    recall  f1-score   support
#
#         Left     0.5233    0.4618    0.4906       340
#        Right     0.5081    0.5693    0.5369       332
#
#     accuracy                         0.5149       672
#    macro avg     0.5157    0.5155    0.5138       672
# weighted avg     0.5158    0.5149    0.5135       672
#
#
# ======================================================================
# LDA Experiment : 109 Subjects
# ======================================================================
# Train Accuracy : 0.5105 (51.05%)
# Test Accuracy  : 0.5085 (50.85%)
# Accuracy Gap   : 0.21%
#
# Test Confusion Matrix
# [[454 258]
#  [439 267]]
#
# Test Classification Report
#               precision    recall  f1-score   support
#
#         Left     0.5084    0.6376    0.5657       712
#        Right     0.5086    0.3782    0.4338       706
#
#     accuracy                         0.5085      1418
#    macro avg     0.5085    0.5079    0.4998      1418
# weighted avg     0.5085    0.5085    0.5000      1418

# %%
print("\n" + "=" * 85)
print("CSP + LDA FINAL RESULTS")
print("=" * 85)

print(
    f"{'Subjects':<12}"
    f"{'Train Acc':<15}"
    f"{'Test Acc':<15}"
    f"{'Gap':<15}"
)

print("-" * 57)

for n_subjects in SUBJECT_EXPERIMENTS:

    train_acc = lda_results[
        n_subjects
    ]["train_accuracy"]

    test_acc = lda_results[
        n_subjects
    ]["test_accuracy"]

    gap = train_acc - test_acc

    print(
        f"{n_subjects:<12}"
        f"{train_acc * 100:<15.2f}"
        f"{test_acc * 100:<15.2f}"
        f"{gap * 100:<15.2f}"
    )
# Out:
# =====================================================================================
# CSP + LDA FINAL RESULTS
# =====================================================================================
# Subjects    Train Acc      Test Acc       Gap
# ---------------------------------------------------------
# 10          65.71          51.11          14.60
# 20          54.92          50.74          4.18
# 50          52.89          51.49          1.40
# 109         51.05          50.85          0.21
